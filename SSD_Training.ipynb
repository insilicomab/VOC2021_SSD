# %% [markdown]
# # データセットと学習済み重みのダウンロード

# %%
'''
1. データセット用フォルダー「data」と
   学習済みの重み用フォルダー「weight」の作成
'''
import os

# 「data」フォルダーを作成
data_dir = "./data/"
if not os.path.exists(data_dir):
    os.mkdir(data_dir)

# 「weights」フォルダーを作成
weights_dir = "./weights/"
if not os.path.exists(weights_dir):
    os.mkdir(weights_dir)

# %%
# %%time
'''
2. VOC2012のデータセットを
   Visual Object Classes Challenge 2012のサイトからダウンロード
'''
import urllib.request
import tarfile

# VOCデータセットのダウンロード先のURL
url = "http://host.robots.ox.ac.uk/pascal/VOC/voc2012/VOCtrainval_11-May-2012.tar"
# data_dirにファイル名を連結してファイルパスを作成
target_path = os.path.join(data_dir, "VOCtrainval_11-May-2012.tar") 

if not os.path.exists(target_path):
    # urlにアクセスしてファイルパスtarget_pathとしてダウンロード
    urllib.request.urlretrieve(url, target_path)
    # ダウンロードしたtar形式ファイルを読み込む
    tar = tarfile.TarFile(target_path)
    tar.extractall(data_dir)  # tarファイルを解凍
    tar.close()               # tarファイルをクローズ
# Out:
# CPU times: user 7.72 s, sys: 8.3 s, total: 16 s
# Wall time: 1min 49s

# %%
# %%time
'''
3. SSDで使用するVGG16の学習済みの重みを
  「weights」フォルダーにダウンロード
'''
# VGG16の学習済み重みのダウンロード先
url = "https://s3.amazonaws.com/amdegroot-models/vgg16_reducedfc.pth"
# weights_dirにファイル名を連結してファイルパスを作成
target_path = os.path.join(weights_dir, "vgg16_reducedfc.pth") 

if not os.path.exists(target_path):
    # urlにアクセスしてファイルパスtarget_pathとしてダウンロード
    urllib.request.urlretrieve(url, target_path)
# Out:
# CPU times: user 160 ms, sys: 115 ms, total: 275 ms
# Wall time: 2.92 s

# %%
# %%time
'''
4. SSD300の学習済みの重みを
  「weights」フォルダーにダウンロード
'''
# SSD300の学習済み重みのダウンロード先
url = "https://s3.amazonaws.com/amdegroot-models/ssd300_mAP_77.43_v2.pth"
# weights_dirにファイル名を連結してファイルパスを作成
target_path = os.path.join(weights_dir, "ssd300_mAP_77.43_v2.pth") 

if not os.path.exists(target_path):
    # urlにアクセスしてファイルパスtarget_pathとしてダウンロード
    urllib.request.urlretrieve(url, target_path)
# Out:
# CPU times: user 217 ms, sys: 147 ms, total: 364 ms
# Wall time: 3.36 s

# %%
# Googleドライブのマウント
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
! ls
# Out:
# data  drive  sample_data  weights

# %%
'''
1. GPUが使用可能であればデバイスに割り当てる
'''
import torch
# GPUが使用可能であれば割り当てる
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print('使用されるデバイス：', device)
# Out:
# 使用されるデバイス： cuda

# %%
'''
2. 「ObjectDetection」内のモジュールをインポート可能にする
'''
import sys

# モジュールのインポートが行えるように「VOC2021_SSDのパスを登録
# 以下のパスは環境に合わせて書き換える必要があります
sys.path.append('/content/drive/My Drive/Colab Notebooks/VOC2021_SSD')

# %%
'''
3. データローダーの作成
'''
import torch.utils.data as data
# vocモジュールからインポート
from voc import make_filepath_list, GetBBoxAndLabel, DataTransform, \
                PreprocessVOC2012, multiobject_collate_fn

# データセットの親フォルダーのパス
# 以下のパスは環境に合わせて書き換える必要があります
rootpath = "./data/VOCdevkit/VOC2012/"
# 訓練用、検証用の画像、アノテーションデータのファイルパスのリストを作成
train_img_list, train_anno_list, val_img_list, val_anno_list = make_filepath_list(
    rootpath)

# VOC2012の正解ラベルのリスト
voc_classes = [
    'aeroplane', 'bicycle', 'bird', 'boat', 'bottle',
    'bus', 'car', 'cat', 'chair', 'cow',
    'diningtable', 'dog', 'horse', 'motorbike',
    'person', 'pottedplant', 'sheep', 'sofa', 'train',
    'tvmonitor']

# データセットのRGBの平均値(R)123,(G)117,(B)104をOpenCVのBGRの並びに合わせて
# (104, 117, 123)のタプルにする
color_mean = (104, 117, 123)

# 画像を入力サイズを300×300にする
input_size = 300

# DataTransformでVOC2012データセットを前処理して以下のデータを取得
#  ・前処理後のイメージ[R,G,B](Tensor)
#  ・BBoxとラベル(ndarray)
#  ・イメージの高さ、幅(int)
train_dataset = PreprocessVOC2012(
    train_img_list,  # イメージのパスリスト
    train_anno_list, # アノテーションのパスリスト
    phase="train",   # 訓練モード
    transform=DataTransform(input_size, color_mean), # 前処理オブジェクト
    get_bbox_label=GetBBoxAndLabel(voc_classes)) # BBoxとラベル取得

val_dataset = PreprocessVOC2012(
    val_img_list,  # イメージのパスリスト
    val_anno_list, # アノテーションのパスリスト
    phase="val",   # 訓練モード
    transform=DataTransform(input_size, color_mean), # 前処理オブジェクト
    get_bbox_label=GetBBoxAndLabel(voc_classes)) # BBoxとラベル取得

batch_size = 32 # 1バッチあたりのデータ数は32

# 訓練用のミニバッチを生成するデータローダー
train_dataloader = data.DataLoader(
    train_dataset,         # 前処理した訓練データ
    batch_size=batch_size, # バッチサイズ
    shuffle=True, # ミニバッチ抽出の際にシャッフルする
    collate_fn=multiobject_collate_fn) # ミニバッチ生成関数

# 検証用のミニバッチを生成するデータローダー
val_dataloader = data.DataLoader(
    val_dataset,           # 前処理した検証データ
    batch_size=batch_size, # バッチサイズ
    shuffle=False, # ミニバッチ抽出の際にシャッフルしない
    collate_fn=multiobject_collate_fn) # ミニバッチ生成関数

# 辞書オブジェクトにまとめる
dataloaders_dict = {"train": train_dataloader, "val": val_dataloader}

# %%
'''
4. torchinfoをpipコマンドでインストールする
'''
! pip install torchinfo
# Out:
# Collecting torchinfo
#   Downloading torchinfo-1.6.3-py3-none-any.whl (20 kB)
# Installing collected packages: torchinfo
# Successfully installed torchinfo-1.6.3

# %%
'''
5. SSDモデルの作成
'''
import torch.nn as nn
import torch.nn.init as init
from ssd import SSD # ssdモジュールのインポート
from torchinfo import summary

# SSDモデルの設定値
ssd_cfg = {
    'classes_num': 21,  # 背景クラスを含めた合計クラス数
    'input_size': 300,  # 画像の入力サイズ
    'dbox_num': [4, 6, 6, 6, 4, 4],  # DBoxのアスペクト比の種類
    'feature_maps': [38, 19, 10, 5, 3, 1],  # 各sourceの画像サイズ
    'steps': [8, 16, 32, 64, 100, 300],  # DBOXの大きさを決める
    'min_sizes': [30, 60, 111, 162, 213, 264],  # DBOXの大きさを決める
    'max_sizes': [60, 111, 162, 213, 264, 315],  # DBOXの大きさを決める
    'aspect_ratios': [[2], [2, 3], [2, 3], [2, 3], [2], [2]],
}

# SSDモデルを生成
net = SSD(phase='train', # 訓練モード
          cfg=ssd_cfg)   # 設定値のdictオブジェクト

# SSDの初期の重みを設定
# VGG16の学習済み重みを取得
vgg_weights = torch.load(
    '/content/drive/MyDrive/Colab Notebooks/VOC2021_SSD/weights/vgg16_reducedfc.pth')
# SSDのvggネットワークの重みとしてロード
net.vgg.load_state_dict(vgg_weights)

# SSDモデルのvgg以外のネットワークの重みはHeの初期値で初期化
def weights_init(m):
    if isinstance(m, nn.Conv2d):
        init.kaiming_normal_(m.weight.data)
        if m.bias is not None:  # バイアス項がある場合
            nn.init.constant_(m.bias, 0.0)

# Heの初期値を適用
net.extras.apply(weights_init) # extrasネットワーク
net.loc.apply(weights_init)    # locネットワーク
net.conf.apply(weights_init)   #confネットワーク

# SSDモデルのサマリを出力
summary(
    net,
    # バッチを含む入力のサイズを設定
    input_size=(batch_size, 3, 300, 300),
    # レイヤーへの入力、出力のサイズとパラメーター数を出力
    col_names=['input_size','output_size', 'num_params'])
# Out:
# ===================================================================================================================
# Layer (type:depth-idx)                   Input Shape               Output Shape              Param #
# ===================================================================================================================
# SSD                                      --                        --                        --
# ├─ModuleList: 1-1                        --                        --                        --
# ├─ModuleList: 1-2                        --                        --                        --
# ├─ModuleList: 1-3                        --                        --                        --
# ├─ModuleList: 1-4                        --                        --                        --
# ├─ModuleList: 1-1                        --                        --                        --
# │    └─Conv2d: 2-1                       [32, 3, 300, 300]         [32, 64, 300, 300]        1,792
# │    └─ReLU: 2-2                         [32, 64, 300, 300]        [32, 64, 300, 300]        --
# │    └─Conv2d: 2-3                       [32, 64, 300, 300]        [32, 64, 300, 300]        36,928
# │    └─ReLU: 2-4                         [32, 64, 300, 300]        [32, 64, 300, 300]        --
# │    └─MaxPool2d: 2-5                    [32, 64, 300, 300]        [32, 64, 150, 150]        --
# │    └─Conv2d: 2-6                       [32, 64, 150, 150]        [32, 128, 150, 150]       73,856
# │    └─ReLU: 2-7                         [32, 128, 150, 150]       [32, 128, 150, 150]       --
# │    └─Conv2d: 2-8                       [32, 128, 150, 150]       [32, 128, 150, 150]       147,584
# │    └─ReLU: 2-9                         [32, 128, 150, 150]       [32, 128, 150, 150]       --
# │    └─MaxPool2d: 2-10                   [32, 128, 150, 150]       [32, 128, 75, 75]         --
# │    └─Conv2d: 2-11                      [32, 128, 75, 75]         [32, 256, 75, 75]         295,168
# │    └─ReLU: 2-12                        [32, 256, 75, 75]         [32, 256, 75, 75]         --
# │    └─Conv2d: 2-13                      [32, 256, 75, 75]         [32, 256, 75, 75]         590,080
# │    └─ReLU: 2-14                        [32, 256, 75, 75]         [32, 256, 75, 75]         --
# │    └─Conv2d: 2-15                      [32, 256, 75, 75]         [32, 256, 75, 75]         590,080
# │    └─ReLU: 2-16                        [32, 256, 75, 75]         [32, 256, 75, 75]         --
# │    └─MaxPool2d: 2-17                   [32, 256, 75, 75]         [32, 256, 38, 38]         --
# │    └─Conv2d: 2-18                      [32, 256, 38, 38]         [32, 512, 38, 38]         1,180,160
# │    └─ReLU: 2-19                        [32, 512, 38, 38]         [32, 512, 38, 38]         --
# │    └─Conv2d: 2-20                      [32, 512, 38, 38]         [32, 512, 38, 38]         2,359,808
# │    └─ReLU: 2-21                        [32, 512, 38, 38]         [32, 512, 38, 38]         --
# │    └─Conv2d: 2-22                      [32, 512, 38, 38]         [32, 512, 38, 38]         2,359,808
# │    └─ReLU: 2-23                        [32, 512, 38, 38]         [32, 512, 38, 38]         --
# ├─L2Norm: 1-5                            [32, 512, 38, 38]         [32, 512, 38, 38]         512
# ├─ModuleList: 1-1                        --                        --                        --
# │    └─MaxPool2d: 2-24                   [32, 512, 38, 38]         [32, 512, 19, 19]         --
# │    └─Conv2d: 2-25                      [32, 512, 19, 19]         [32, 512, 19, 19]         2,359,808
# │    └─ReLU: 2-26                        [32, 512, 19, 19]         [32, 512, 19, 19]         --
# │    └─Conv2d: 2-27                      [32, 512, 19, 19]         [32, 512, 19, 19]         2,359,808
# │    └─ReLU: 2-28                        [32, 512, 19, 19]         [32, 512, 19, 19]         --
# │    └─Conv2d: 2-29                      [32, 512, 19, 19]         [32, 512, 19, 19]         2,359,808
# │    └─ReLU: 2-30                        [32, 512, 19, 19]         [32, 512, 19, 19]         --
# │    └─MaxPool2d: 2-31                   [32, 512, 19, 19]         [32, 512, 19, 19]         --
# │    └─Conv2d: 2-32                      [32, 512, 19, 19]         [32, 1024, 19, 19]        4,719,616
# │    └─ReLU: 2-33                        [32, 1024, 19, 19]        [32, 1024, 19, 19]        --
# │    └─Conv2d: 2-34                      [32, 1024, 19, 19]        [32, 1024, 19, 19]        1,049,600
# │    └─ReLU: 2-35                        [32, 1024, 19, 19]        [32, 1024, 19, 19]        --
# ├─ModuleList: 1-2                        --                        --                        --
# │    └─Conv2d: 2-36                      [32, 1024, 19, 19]        [32, 256, 19, 19]         262,400
# │    └─Conv2d: 2-37                      [32, 256, 19, 19]         [32, 512, 10, 10]         1,180,160
# │    └─Conv2d: 2-38                      [32, 512, 10, 10]         [32, 128, 10, 10]         65,664
# │    └─Conv2d: 2-39                      [32, 128, 10, 10]         [32, 256, 5, 5]           295,168
# │    └─Conv2d: 2-40                      [32, 256, 5, 5]           [32, 128, 5, 5]           32,896
# │    └─Conv2d: 2-41                      [32, 128, 5, 5]           [32, 256, 3, 3]           295,168
# │    └─Conv2d: 2-42                      [32, 256, 3, 3]           [32, 128, 3, 3]           32,896
# │    └─Conv2d: 2-43                      [32, 128, 3, 3]           [32, 256, 1, 1]           295,168
# ├─ModuleList: 1-3                        --                        --                        --
# │    └─Conv2d: 2-44                      [32, 512, 38, 38]         [32, 16, 38, 38]          73,744
# ├─ModuleList: 1-4                        --                        --                        --
# │    └─Conv2d: 2-45                      [32, 512, 38, 38]         [32, 84, 38, 38]          387,156
# ├─ModuleList: 1-3                        --                        --                        --
# │    └─Conv2d: 2-46                      [32, 1024, 19, 19]        [32, 24, 19, 19]          221,208
# ├─ModuleList: 1-4                        --                        --                        --
# │    └─Conv2d: 2-47                      [32, 1024, 19, 19]        [32, 126, 19, 19]         1,161,342
# ├─ModuleList: 1-3                        --                        --                        --
# │    └─Conv2d: 2-48                      [32, 512, 10, 10]         [32, 24, 10, 10]          110,616
# ├─ModuleList: 1-4                        --                        --                        --
# │    └─Conv2d: 2-49                      [32, 512, 10, 10]         [32, 126, 10, 10]         580,734
# ├─ModuleList: 1-3                        --                        --                        --
# │    └─Conv2d: 2-50                      [32, 256, 5, 5]           [32, 24, 5, 5]            55,320
# ├─ModuleList: 1-4                        --                        --                        --
# │    └─Conv2d: 2-51                      [32, 256, 5, 5]           [32, 126, 5, 5]           290,430
# ├─ModuleList: 1-3                        --                        --                        --
# │    └─Conv2d: 2-52                      [32, 256, 3, 3]           [32, 16, 3, 3]            36,880
# ├─ModuleList: 1-4                        --                        --                        --
# │    └─Conv2d: 2-53                      [32, 256, 3, 3]           [32, 84, 3, 3]            193,620
# ├─ModuleList: 1-3                        --                        --                        --
# │    └─Conv2d: 2-54                      [32, 256, 1, 1]           [32, 16, 1, 1]            36,880
# ├─ModuleList: 1-4                        --                        --                        --
# │    └─Conv2d: 2-55                      [32, 256, 1, 1]           [32, 84, 1, 1]            193,620
# ===================================================================================================================
# Total params: 26,285,486
# Trainable params: 26,285,486
# Non-trainable params: 0
# Total mult-adds (T): 1.00
# ===================================================================================================================
# Input size (MB): 34.56
# Forward/backward pass size (MB): 6717.23
# Params size (MB): 105.14
# Estimated Total Size (MB): 6856.93
# ===================================================================================================================

# %%
'''
6. 損失関数とオプティマイザーの作成
'''
import torch.optim as optim
from ssd import MultiBoxLoss

# 損失関数のオブジェクトを生成
criterion = MultiBoxLoss(
    jaccard_thresh=0.5, # 背景のDBoxに分類するときのIoUの閾値
    neg_pos=3, # 背景のDBoxの数はPositive DBoxの何倍にするか
    device=device) # ネットワークのTensorに割り当てるデバイス

# 勾配降下アルゴリズムを使用するオプティマイザーを生成
optimizer = optim.SGD(
    net.parameters(),  # SSDモデルのパラメーター
    lr=1e-3,           # 学習率
    momentum=0.9,      # 慣性項に割り当てる係数
    weight_decay=5e-4) # 重み更新時のL2正則化の係数

# %%
'''
7. SSDモデルの学習(パラメーターの更新)を行う関数
'''
import time
import pandas as pd

def train(net, dataloaders_dict, criterion, optimizer, num_epochs):
    '''
    Parameters:
      net(object): SSDモデル
      dataloaders_dict(objectのdict): データーローダー
      criterion(object): 損失関数
      optimizer(object): オプティマイザー
      num_epochs(object): 学習回数
    '''
    # SSDモデルでGPUを使用
    net.to(device)

    # ネットワークの構成に対して最適なアルゴリズムを見つけて高速化させる
    torch.backends.cudnn.benchmark = True

    iteration = 1          # イテレーション(ステップ)カウンター
    epoch_train_loss = 0.0 # 訓練1エポックごとの損失和
    epoch_val_loss = 0.0   # 検証1エポックごとの損失和
    logs = []              # 損失のログを記録するリスト

    # 学習、または検証のエポックごとのループ
    for epoch in range(num_epochs):
        # 開始時刻を保存
        t_epoch_start = time.time()
        t_iter_start = time.time()

        # 現在のエポック数を出力
        print('---------------------------------------')
        print('Epoch {}/{}'.format(epoch+1, num_epochs))
        print('---------------------------------------')

        # エポック10回につき検証を1回行う
        for phase in ['train', 'val']:
            # エポックが10回に達するまではモデルを訓練モードにする
            if phase == 'train':
                net.train()  # モデルを訓練モードにする
            else:
                # エポックが10回に達していたらモデルを検証モードにして検証開始
                if((epoch+1) % 10 == 0):
                    net.eval()   # モデルを検証モードにする
                    print('---------------------------------------')
                    print('（validation）')
                else:
                    # 10回に達していなければ次のエポックに進む
                    continue

            # 1ステップにおけるミニバッチを使用した学習または検証
            # データローダーをイテレートしてミニバッチを抽出
            for images, targets in dataloaders_dict[phase]:
                # 画像データにデバイスを割り当てる
                images = images.to(device)
                # 教師データ(正解BBoxのアノテーション情報)
                # (バッチサイズ, 物体数, 5[xmin, ymin, xmax, ymax, label_index])
                # にデバイスを割り当てる
                targets = [ann.to(device) for ann in targets]

                # optimizerが保持する勾配を0で初期化(累積しないように)
                optimizer.zero_grad()

                # 順伝搬（forward）とバックプロパゲーション(訓練時のみ)
                with torch.set_grad_enabled(phase == 'train'):
                    # 順伝搬（forward）を行って(loc, conf, dbox_list)を取得
                    # ・locの出力(バッチサイズ, 8732, 4[Δcx, Δcy, Δw, Δh])
                    # ・confの出力(バッチサイズ, 8732, 21)
                    # ・DBoxの情報(8732, 4[cx, cy, width, height])
                    outputs = net(images)

                    # Positive DBoxのオフセット情報の損失平均
                    # ミニバッチにおけるPositive DBoxの確信度の損失平均
                    loss_l, loss_c = criterion(outputs, targets)
                    # 2つの損失を合計する
                    loss = loss_l + loss_c

                    # 訓練時はバックプロパゲーションによるパラメーター更新を行う
                    if phase == 'train':
                        loss.backward()  # バックプロパゲーション

                        # 勾配が大きすぎると不安定になるので
                        # clipで勾配の上限を2.0に制限する
                        nn.utils.clip_grad_value_(net.parameters(),
                                                  clip_value=2.0)
                        # 勾配降下法の更新式を適用してバイアス、重みを更新
                        optimizer.step()

                        # ミニバッチを10個処理(10ステップ)ごとに損失を出力
                        if (iteration % 10 == 0):
                            # 10ステップの所要時間を取得
                            t_iter_finish = time.time()
                            duration = t_iter_finish - t_iter_start
                            # ステップ数、損失、所要時間を出力
                            print('ステップ( {} )  loss: {:.4f} -- time: {:.4f} sec.'.format(
                                iteration, loss.item(), duration))
                            t_iter_start = time.time()

                        # エポックの損失をepoch_train_lossに加算する
                        epoch_train_loss += loss.item()
                        # ステップ数を1増やす
                        iteration += 1

                    # 検証モードでは順伝播後の損失の記録のみを行う
                    else:
                        epoch_val_loss += loss.item()

        # epochのphaseごとのlossと正解率
        # エポック終了時の時刻を取得
        t_epoch_finish = time.time()
        print('---------------------------------------')
        # 訓練データの損失と検証データの損失を出力
        print('train_loss: {:.4f} - val_loss(Every 10 epochs): {:.4f}'.format(
            epoch_train_loss, epoch_val_loss))
        # エポック終了までに要した時間を取得
        print('time:  {:.4f} sec.'.format(t_epoch_finish - t_epoch_start))
        # 次のエポックの開始時刻を取得
        t_epoch_start = time.time()

        # エポックごとに損失をdictオブジェクトに保存
        log_epoch = {'epoch': epoch+1,
                     'train_loss': epoch_train_loss,
                     'val_loss': epoch_val_loss}
        # ログのリストに追加
        logs.append(log_epoch)
        # ログのリストをデータフレームに変換
        df = pd.DataFrame(logs)
        # ログファイルに保存
        df.to_csv('/content/drive/MyDrive/Colab Notebooks/VOC2021_SSD/epoch_loss.csv')

        # 訓練時の損失和を0で初期化
        epoch_train_loss = 0.0
        # 検証時の損失和を0で初期化
        epoch_val_loss = 0.0

        # 1エポック終了ごとにモデルのパラメーター値を保存
        if ((epoch+1) % 10 == 0):
            torch.save(
                net.state_dict(),
                '/content/drive/MyDrive/Colab Notebooks/VOC2021_SSD/weights/ssd_weights' +
                str(epoch+1) + '.pth')
            print('--saved weights--')

# %%
# %%time
'''
8. VOC2012データセットをSSDモデルで学習
'''
num_epochs= 50 # 学習回数(エポック数)は50

train(net,                   # SSDモデル
      dataloaders_dict,      # データローダー
      criterion,             # 損失関数
      optimizer,             # オプティマイザー
      num_epochs=num_epochs) # エポック数
# Out:
# ---------------------------------------
# Epoch 1/50
# ---------------------------------------
# ステップ( 10 )  loss: 16.3511 -- time: 19.2979 sec.
# ステップ( 20 )  loss: 13.2701 -- time: 14.0174 sec.
# ステップ( 30 )  loss: 10.0815 -- time: 14.2885 sec.
# ステップ( 40 )  loss: 10.2929 -- time: 14.2889 sec.
# ステップ( 50 )  loss: 11.2859 -- time: 14.3024 sec.
# ステップ( 60 )  loss: 9.4437 -- time: 14.3668 sec.
# ステップ( 70 )  loss: 8.8823 -- time: 13.9212 sec.
# ステップ( 80 )  loss: 8.2995 -- time: 14.3094 sec.
# ステップ( 90 )  loss: 8.7937 -- time: 14.1796 sec.
# ステップ( 100 )  loss: 8.4553 -- time: 14.3252 sec.
# ステップ( 110 )  loss: 8.0809 -- time: 14.1647 sec.
# ステップ( 120 )  loss: 8.1018 -- time: 14.3356 sec.
# ステップ( 130 )  loss: 7.7229 -- time: 14.5227 sec.
# ステップ( 140 )  loss: 7.6691 -- time: 14.6427 sec.
# ステップ( 150 )  loss: 9.8486 -- time: 14.8758 sec.
# ステップ( 160 )  loss: 8.4884 -- time: 14.7506 sec.
# ステップ( 170 )  loss: 10.0935 -- time: 14.5467 sec.
# ---------------------------------------
# train_loss: 1791.4991 - val_loss(Every 10 epochs): 0.0000
# time:  279.5780 sec.
# ---------------------------------------
# Epoch 2/50
# ---------------------------------------
# ステップ( 180 )  loss: 8.2134 -- time: 0.9065 sec.
# ステップ( 190 )  loss: 8.3448 -- time: 14.3086 sec.
# ステップ( 200 )  loss: 8.9897 -- time: 14.2799 sec.
# ステップ( 210 )  loss: 9.0170 -- time: 14.3211 sec.
# ステップ( 220 )  loss: 8.9452 -- time: 14.0860 sec.
# ステップ( 230 )  loss: 8.4473 -- time: 14.1813 sec.
# ステップ( 240 )  loss: 9.1526 -- time: 14.3116 sec.
# ステップ( 250 )  loss: 8.4694 -- time: 14.5059 sec.
# ステップ( 260 )  loss: 8.7827 -- time: 14.6014 sec.
# ステップ( 270 )  loss: 9.2697 -- time: 14.5087 sec.
# ステップ( 280 )  loss: 7.0804 -- time: 14.6379 sec.
# ステップ( 290 )  loss: 8.0154 -- time: 14.5409 sec.
# ステップ( 300 )  loss: 7.6146 -- time: 14.4223 sec.
# ステップ( 310 )  loss: 8.3993 -- time: 14.2678 sec.
# ステップ( 320 )  loss: 9.0365 -- time: 14.3537 sec.
# ステップ( 330 )  loss: 8.4853 -- time: 14.1670 sec.
# ステップ( 340 )  loss: 7.8160 -- time: 14.6426 sec.
# ステップ( 350 )  loss: 7.0441 -- time: 14.2447 sec.
# ---------------------------------------
# train_loss: 1494.5106 - val_loss(Every 10 epochs): 0.0000
# time:  267.7606 sec.
# ---------------------------------------
# Epoch 3/50
# ---------------------------------------
# ステップ( 360 )  loss: 7.4635 -- time: 2.4346 sec.
# ステップ( 370 )  loss: 7.4600 -- time: 14.2914 sec.
# ステップ( 380 )  loss: 8.1685 -- time: 14.4326 sec.
# ステップ( 390 )  loss: 7.3136 -- time: 14.2562 sec.
# ステップ( 400 )  loss: 8.0275 -- time: 14.4149 sec.
# ステップ( 410 )  loss: 8.2851 -- time: 14.6377 sec.
# ステップ( 420 )  loss: 7.3659 -- time: 14.4935 sec.
# ステップ( 430 )  loss: 7.1696 -- time: 14.4055 sec.
# ステップ( 440 )  loss: 7.3248 -- time: 14.5421 sec.
# ステップ( 450 )  loss: 6.8878 -- time: 14.3491 sec.
# ステップ( 460 )  loss: 6.8737 -- time: 14.5445 sec.
# ステップ( 470 )  loss: 7.3707 -- time: 14.3049 sec.
# ステップ( 480 )  loss: 6.5839 -- time: 14.3381 sec.
# ステップ( 490 )  loss: 7.9239 -- time: 14.2256 sec.
# ステップ( 500 )  loss: 8.0581 -- time: 14.2043 sec.
# ステップ( 510 )  loss: 7.0889 -- time: 14.4487 sec.
# ステップ( 520 )  loss: 7.2149 -- time: 14.5113 sec.
# ステップ( 530 )  loss: 7.2219 -- time: 14.3953 sec.
# ---------------------------------------
# train_loss: 1321.2698 - val_loss(Every 10 epochs): 0.0000
# time:  267.9224 sec.
# ---------------------------------------
# Epoch 4/50
# ---------------------------------------
# ステップ( 540 )  loss: 7.2696 -- time: 3.8037 sec.
# ステップ( 550 )  loss: 7.1810 -- time: 14.2288 sec.
# ステップ( 560 )  loss: 7.3482 -- time: 14.1067 sec.
# ステップ( 570 )  loss: 7.2049 -- time: 14.2478 sec.
# ステップ( 580 )  loss: 6.7223 -- time: 14.4631 sec.
# ステップ( 590 )  loss: 6.8654 -- time: 14.2444 sec.
# ステップ( 600 )  loss: 6.2351 -- time: 14.3202 sec.
# ステップ( 610 )  loss: 6.9995 -- time: 14.3779 sec.
# ステップ( 620 )  loss: 6.5477 -- time: 14.2033 sec.
# ステップ( 630 )  loss: 6.8514 -- time: 14.5671 sec.
# ステップ( 640 )  loss: 6.7176 -- time: 14.4817 sec.
# ステップ( 650 )  loss: 7.2974 -- time: 14.4749 sec.
# ステップ( 660 )  loss: 6.4286 -- time: 14.1311 sec.
# ステップ( 670 )  loss: 6.7527 -- time: 14.5804 sec.
# ステップ( 680 )  loss: 6.6533 -- time: 14.4377 sec.
# ステップ( 690 )  loss: 7.0081 -- time: 14.5340 sec.
# ステップ( 700 )  loss: 6.5625 -- time: 14.3442 sec.
# ステップ( 710 )  loss: 6.4277 -- time: 14.3604 sec.
# ---------------------------------------
# train_loss: 1224.1409 - val_loss(Every 10 epochs): 0.0000
# time:  267.2385 sec.
# ---------------------------------------
# Epoch 5/50
# ---------------------------------------
# ステップ( 720 )  loss: 6.2266 -- time: 5.3543 sec.
# ステップ( 730 )  loss: 6.9203 -- time: 14.4033 sec.
# ステップ( 740 )  loss: 7.2466 -- time: 14.5347 sec.
# ステップ( 750 )  loss: 7.0381 -- time: 14.0595 sec.
# ステップ( 760 )  loss: 6.6676 -- time: 14.1651 sec.
# ステップ( 770 )  loss: 6.9479 -- time: 14.6147 sec.
# ステップ( 780 )  loss: 6.3042 -- time: 14.5279 sec.
# ステップ( 790 )  loss: 6.4143 -- time: 14.1322 sec.
# ステップ( 800 )  loss: 6.4622 -- time: 14.2759 sec.
# ステップ( 810 )  loss: 6.4320 -- time: 14.7480 sec.
# ステップ( 820 )  loss: 6.8371 -- time: 14.3576 sec.
# ステップ( 830 )  loss: 6.2485 -- time: 14.2399 sec.
# ステップ( 840 )  loss: 6.3196 -- time: 14.1908 sec.
# ステップ( 850 )  loss: 6.1277 -- time: 14.2052 sec.
# ステップ( 860 )  loss: 6.7425 -- time: 14.3237 sec.
# ステップ( 870 )  loss: 6.6570 -- time: 14.4544 sec.
# ステップ( 880 )  loss: 6.7434 -- time: 14.2519 sec.
# ステップ( 890 )  loss: 6.9837 -- time: 14.2366 sec.
# ---------------------------------------
# train_loss: 1178.2987 - val_loss(Every 10 epochs): 0.0000
# time:  267.0458 sec.
# ---------------------------------------
# Epoch 6/50
# ---------------------------------------
# ステップ( 900 )  loss: 6.2253 -- time: 6.9041 sec.
# ステップ( 910 )  loss: 6.5659 -- time: 14.1498 sec.
# ステップ( 920 )  loss: 6.0515 -- time: 14.4996 sec.
# ステップ( 930 )  loss: 6.1422 -- time: 14.2719 sec.
# ステップ( 940 )  loss: 6.7302 -- time: 14.4340 sec.
# ステップ( 950 )  loss: 6.2058 -- time: 14.2986 sec.
# ステップ( 960 )  loss: 6.1701 -- time: 14.5611 sec.
# ステップ( 970 )  loss: 6.1061 -- time: 14.2006 sec.
# ステップ( 980 )  loss: 6.1984 -- time: 14.1458 sec.
# ステップ( 990 )  loss: 6.1081 -- time: 14.3525 sec.
# ステップ( 1000 )  loss: 6.1641 -- time: 14.2245 sec.
# ステップ( 1010 )  loss: 6.3425 -- time: 14.1724 sec.
# ステップ( 1020 )  loss: 6.2960 -- time: 14.3233 sec.
# ステップ( 1030 )  loss: 6.3652 -- time: 14.1443 sec.
# ステップ( 1040 )  loss: 5.8482 -- time: 14.3159 sec.
# ステップ( 1050 )  loss: 6.4876 -- time: 14.3966 sec.
# ステップ( 1060 )  loss: 5.8688 -- time: 14.1348 sec.
# ステップ( 1070 )  loss: 6.1868 -- time: 14.4389 sec.
# ---------------------------------------
# train_loss: 1120.0768 - val_loss(Every 10 epochs): 0.0000
# time:  266.3114 sec.
# ---------------------------------------
# Epoch 7/50
# ---------------------------------------
# ステップ( 1080 )  loss: 5.7737 -- time: 8.5336 sec.
# ステップ( 1090 )  loss: 6.2101 -- time: 14.3980 sec.
# ステップ( 1100 )  loss: 5.7077 -- time: 14.1436 sec.
# ステップ( 1110 )  loss: 5.9799 -- time: 14.1863 sec.
# ステップ( 1120 )  loss: 5.7724 -- time: 14.3616 sec.
# ステップ( 1130 )  loss: 6.0932 -- time: 14.3614 sec.
# ステップ( 1140 )  loss: 6.1068 -- time: 14.2341 sec.
# ステップ( 1150 )  loss: 5.8491 -- time: 14.4433 sec.
# ステップ( 1160 )  loss: 5.9673 -- time: 14.1333 sec.
# ステップ( 1170 )  loss: 6.4945 -- time: 14.5099 sec.
# ステップ( 1180 )  loss: 6.0378 -- time: 14.2230 sec.
# ステップ( 1190 )  loss: 5.9943 -- time: 14.2655 sec.
# ステップ( 1200 )  loss: 5.7940 -- time: 14.3611 sec.
# ステップ( 1210 )  loss: 5.9926 -- time: 14.0143 sec.
# ステップ( 1220 )  loss: 5.8982 -- time: 14.3420 sec.
# ステップ( 1230 )  loss: 6.0250 -- time: 14.1976 sec.
# ステップ( 1240 )  loss: 6.5224 -- time: 14.5949 sec.
# ステップ( 1250 )  loss: 6.3319 -- time: 14.3154 sec.
# ---------------------------------------
# train_loss: 1080.1945 - val_loss(Every 10 epochs): 0.0000
# time:  266.4151 sec.
# ---------------------------------------
# Epoch 8/50
# ---------------------------------------
# ステップ( 1260 )  loss: 5.7353 -- time: 9.7982 sec.
# ステップ( 1270 )  loss: 5.8934 -- time: 14.0001 sec.
# ステップ( 1280 )  loss: 5.9135 -- time: 14.5376 sec.
# ステップ( 1290 )  loss: 6.1790 -- time: 14.5032 sec.
# ステップ( 1300 )  loss: 5.7712 -- time: 14.3323 sec.
# ステップ( 1310 )  loss: 6.1548 -- time: 14.2902 sec.
# ステップ( 1320 )  loss: 5.5629 -- time: 14.4517 sec.
# ステップ( 1330 )  loss: 5.4844 -- time: 14.3321 sec.
# ステップ( 1340 )  loss: 6.0247 -- time: 14.1941 sec.
# ステップ( 1350 )  loss: 5.8470 -- time: 14.3054 sec.
# ステップ( 1360 )  loss: 6.1211 -- time: 14.2503 sec.
# ステップ( 1370 )  loss: 5.9679 -- time: 14.3677 sec.
# ステップ( 1380 )  loss: 5.7799 -- time: 14.3703 sec.
# ステップ( 1390 )  loss: 5.7140 -- time: 14.1641 sec.
# ステップ( 1400 )  loss: 6.0046 -- time: 14.2170 sec.
# ステップ( 1410 )  loss: 5.9692 -- time: 14.3531 sec.
# ステップ( 1420 )  loss: 5.7899 -- time: 14.4123 sec.
# ステップ( 1430 )  loss: 5.8663 -- time: 14.1948 sec.
# ---------------------------------------
# train_loss: 1047.6678 - val_loss(Every 10 epochs): 0.0000
# time:  266.3249 sec.
# ---------------------------------------
# Epoch 9/50
# ---------------------------------------
# ステップ( 1440 )  loss: 5.2793 -- time: 11.3548 sec.
# ステップ( 1450 )  loss: 6.0867 -- time: 14.3483 sec.
# ステップ( 1460 )  loss: 5.7279 -- time: 14.4188 sec.
# ステップ( 1470 )  loss: 5.7869 -- time: 14.1400 sec.
# ステップ( 1480 )  loss: 5.8557 -- time: 14.3984 sec.
# ステップ( 1490 )  loss: 5.7505 -- time: 14.2975 sec.
# ステップ( 1500 )  loss: 5.5447 -- time: 14.0673 sec.
# ステップ( 1510 )  loss: 6.2449 -- time: 14.1747 sec.
# ステップ( 1520 )  loss: 5.1178 -- time: 14.3860 sec.
# ステップ( 1530 )  loss: 5.8591 -- time: 14.6020 sec.
# ステップ( 1540 )  loss: 5.8609 -- time: 14.1805 sec.
# ステップ( 1550 )  loss: 5.8290 -- time: 14.5457 sec.
# ステップ( 1560 )  loss: 5.3618 -- time: 14.1505 sec.
# ステップ( 1570 )  loss: 5.2864 -- time: 14.1299 sec.
# ステップ( 1580 )  loss: 5.2188 -- time: 14.2965 sec.
# ステップ( 1590 )  loss: 5.4867 -- time: 14.5218 sec.
# ステップ( 1600 )  loss: 5.7255 -- time: 14.1854 sec.
# ステップ( 1610 )  loss: 5.2498 -- time: 14.3338 sec.
# ---------------------------------------
# train_loss: 1018.3980 - val_loss(Every 10 epochs): 0.0000
# time:  266.4067 sec.
# ---------------------------------------
# Epoch 10/50
# ---------------------------------------
# ステップ( 1620 )  loss: 5.2878 -- time: 12.9361 sec.
# ステップ( 1630 )  loss: 5.5470 -- time: 14.0250 sec.
# ステップ( 1640 )  loss: 4.9363 -- time: 14.3854 sec.
# ステップ( 1650 )  loss: 5.8363 -- time: 14.6289 sec.
# ステップ( 1660 )  loss: 5.2452 -- time: 14.5063 sec.
# ステップ( 1670 )  loss: 5.5188 -- time: 14.3147 sec.
# ステップ( 1680 )  loss: 5.4176 -- time: 14.2437 sec.
# ステップ( 1690 )  loss: 4.8833 -- time: 14.2553 sec.
# ステップ( 1700 )  loss: 4.7667 -- time: 14.2200 sec.
# ステップ( 1710 )  loss: 5.6171 -- time: 14.0671 sec.
# ステップ( 1720 )  loss: 5.1444 -- time: 14.4241 sec.
# ステップ( 1730 )  loss: 5.3973 -- time: 14.2151 sec.
# ステップ( 1740 )  loss: 5.6210 -- time: 13.9692 sec.
# ステップ( 1750 )  loss: 5.7238 -- time: 14.2856 sec.
# ステップ( 1760 )  loss: 5.6618 -- time: 14.4893 sec.
# ステップ( 1770 )  loss: 5.3440 -- time: 14.1662 sec.
# ステップ( 1780 )  loss: 5.5373 -- time: 14.2070 sec.
# ステップ( 1790 )  loss: 5.2895 -- time: 13.9960 sec.
# ---------------------------------------
# （validation）
# ---------------------------------------
# train_loss: 990.5811 - val_loss(Every 10 epochs): 994.8013
# time:  377.1813 sec.
# --saved weights--
# ---------------------------------------
# Epoch 11/50
# ---------------------------------------
# ステップ( 1800 )  loss: 5.2913 -- time: 14.2706 sec.
# ステップ( 1810 )  loss: 5.1119 -- time: 14.5132 sec.
# ステップ( 1820 )  loss: 5.5952 -- time: 14.3759 sec.
# ステップ( 1830 )  loss: 5.8931 -- time: 14.1349 sec.
# ステップ( 1840 )  loss: 5.5968 -- time: 14.0746 sec.
# ステップ( 1850 )  loss: 5.4140 -- time: 14.5729 sec.
# ステップ( 1860 )  loss: 4.5376 -- time: 14.3623 sec.
# ステップ( 1870 )  loss: 5.1381 -- time: 14.3430 sec.
# ステップ( 1880 )  loss: 5.5812 -- time: 14.4507 sec.
# ステップ( 1890 )  loss: 5.1878 -- time: 14.4948 sec.
# ステップ( 1900 )  loss: 5.4604 -- time: 14.3576 sec.
# ステップ( 1910 )  loss: 5.0516 -- time: 14.3726 sec.
# ステップ( 1920 )  loss: 5.4290 -- time: 14.1993 sec.
# ステップ( 1930 )  loss: 5.2181 -- time: 14.4944 sec.
# ステップ( 1940 )  loss: 5.1389 -- time: 14.4696 sec.
# ステップ( 1950 )  loss: 5.2033 -- time: 14.2629 sec.
# ステップ( 1960 )  loss: 5.4821 -- time: 14.5640 sec.
# ---------------------------------------
# train_loss: 966.2808 - val_loss(Every 10 epochs): 0.0000
# time:  267.6063 sec.
# ---------------------------------------
# Epoch 12/50
# ---------------------------------------
# ステップ( 1970 )  loss: 5.2422 -- time: 0.9034 sec.
# ステップ( 1980 )  loss: 5.0867 -- time: 14.2888 sec.
# ステップ( 1990 )  loss: 4.8152 -- time: 14.2525 sec.
# ステップ( 2000 )  loss: 5.1739 -- time: 14.3867 sec.
# ステップ( 2010 )  loss: 5.1068 -- time: 14.1225 sec.
# ステップ( 2020 )  loss: 4.8437 -- time: 14.2856 sec.
# ステップ( 2030 )  loss: 4.7514 -- time: 14.3098 sec.
# ステップ( 2040 )  loss: 4.7075 -- time: 14.3501 sec.
# ステップ( 2050 )  loss: 5.3085 -- time: 14.4432 sec.
# ステップ( 2060 )  loss: 5.1821 -- time: 14.2513 sec.
# ステップ( 2070 )  loss: 5.5754 -- time: 14.3064 sec.
# ステップ( 2080 )  loss: 5.1280 -- time: 14.5407 sec.
# ステップ( 2090 )  loss: 5.5732 -- time: 14.4341 sec.
# ステップ( 2100 )  loss: 5.5814 -- time: 14.4865 sec.
# ステップ( 2110 )  loss: 5.2741 -- time: 14.5712 sec.
# ステップ( 2120 )  loss: 5.3812 -- time: 14.4109 sec.
# ステップ( 2130 )  loss: 4.8235 -- time: 14.7230 sec.
# ステップ( 2140 )  loss: 5.1763 -- time: 14.5352 sec.
# ---------------------------------------
# train_loss: 939.8906 - val_loss(Every 10 epochs): 0.0000
# time:  267.9125 sec.
# ---------------------------------------
# Epoch 13/50
# ---------------------------------------
# ステップ( 2150 )  loss: 5.3029 -- time: 2.3201 sec.
# ステップ( 2160 )  loss: 4.9143 -- time: 14.5491 sec.
# ステップ( 2170 )  loss: 4.9528 -- time: 14.2742 sec.
# ステップ( 2180 )  loss: 5.1827 -- time: 14.3085 sec.
# ステップ( 2190 )  loss: 5.1704 -- time: 14.4049 sec.
# ステップ( 2200 )  loss: 5.0646 -- time: 14.3436 sec.
# ステップ( 2210 )  loss: 5.0270 -- time: 14.3173 sec.
# ステップ( 2220 )  loss: 5.1791 -- time: 14.1305 sec.
# ステップ( 2230 )  loss: 5.1195 -- time: 14.2802 sec.
# ステップ( 2240 )  loss: 5.3531 -- time: 14.4374 sec.
# ステップ( 2250 )  loss: 4.8993 -- time: 14.4052 sec.
# ステップ( 2260 )  loss: 4.8502 -- time: 14.3595 sec.
# ステップ( 2270 )  loss: 5.4285 -- time: 14.1815 sec.
# ステップ( 2280 )  loss: 4.9560 -- time: 14.3484 sec.
# ステップ( 2290 )  loss: 5.2158 -- time: 14.5765 sec.
# ステップ( 2300 )  loss: 5.1758 -- time: 14.4359 sec.
# ステップ( 2310 )  loss: 4.9364 -- time: 14.2207 sec.
# ステップ( 2320 )  loss: 5.3698 -- time: 14.4508 sec.
# ---------------------------------------
# train_loss: 920.1676 - val_loss(Every 10 epochs): 0.0000
# time:  267.1681 sec.
# ---------------------------------------
# Epoch 14/50
# ---------------------------------------
# ステップ( 2330 )  loss: 5.1837 -- time: 3.8753 sec.
# ステップ( 2340 )  loss: 4.8592 -- time: 14.4214 sec.
# ステップ( 2350 )  loss: 4.5894 -- time: 14.3406 sec.
# ステップ( 2360 )  loss: 5.0591 -- time: 14.4296 sec.
# ステップ( 2370 )  loss: 5.2957 -- time: 14.3487 sec.
# ステップ( 2380 )  loss: 5.0952 -- time: 14.2425 sec.
# ステップ( 2390 )  loss: 5.3494 -- time: 14.4751 sec.
# ステップ( 2400 )  loss: 4.9201 -- time: 14.2569 sec.
# ステップ( 2410 )  loss: 4.8929 -- time: 14.4584 sec.
# ステップ( 2420 )  loss: 5.0757 -- time: 14.6396 sec.
# ステップ( 2430 )  loss: 5.0487 -- time: 14.0924 sec.
# ステップ( 2440 )  loss: 5.1967 -- time: 14.0763 sec.
# ステップ( 2450 )  loss: 4.8710 -- time: 14.1314 sec.
# ステップ( 2460 )  loss: 4.9712 -- time: 14.3178 sec.
# ステップ( 2470 )  loss: 5.3933 -- time: 14.4738 sec.
# ステップ( 2480 )  loss: 5.3713 -- time: 14.4188 sec.
# ステップ( 2490 )  loss: 5.3098 -- time: 14.3009 sec.
# ステップ( 2500 )  loss: 4.4798 -- time: 14.3985 sec.
# ---------------------------------------
# train_loss: 903.0645 - val_loss(Every 10 epochs): 0.0000
# time:  267.1384 sec.
# ---------------------------------------
# Epoch 15/50
# ---------------------------------------
# ステップ( 2510 )  loss: 4.6034 -- time: 5.2894 sec.
# ステップ( 2520 )  loss: 5.1722 -- time: 14.2460 sec.
# ステップ( 2530 )  loss: 5.0691 -- time: 14.4374 sec.
# ステップ( 2540 )  loss: 4.7761 -- time: 14.3833 sec.
# ステップ( 2550 )  loss: 4.7846 -- time: 14.6142 sec.
# ステップ( 2560 )  loss: 4.9615 -- time: 14.3209 sec.
# ステップ( 2570 )  loss: 5.2009 -- time: 14.1294 sec.
# ステップ( 2580 )  loss: 5.2485 -- time: 14.5351 sec.
# ステップ( 2590 )  loss: 5.0936 -- time: 14.4485 sec.
# ステップ( 2600 )  loss: 4.6406 -- time: 14.1422 sec.
# ステップ( 2610 )  loss: 4.7963 -- time: 14.5783 sec.
# ステップ( 2620 )  loss: 5.3811 -- time: 14.1436 sec.
# ステップ( 2630 )  loss: 5.8602 -- time: 14.2072 sec.
# ステップ( 2640 )  loss: 4.5900 -- time: 14.3517 sec.
# ステップ( 2650 )  loss: 5.1866 -- time: 14.6562 sec.
# ステップ( 2660 )  loss: 5.0101 -- time: 14.2843 sec.
# ステップ( 2670 )  loss: 5.4635 -- time: 14.6340 sec.
# ステップ( 2680 )  loss: 4.7320 -- time: 14.4162 sec.
# ---------------------------------------
# train_loss: 891.8890 - val_loss(Every 10 epochs): 0.0000
# time:  267.6316 sec.
# ---------------------------------------
# Epoch 16/50
# ---------------------------------------
# ステップ( 2690 )  loss: 4.5643 -- time: 6.9598 sec.
# ステップ( 2700 )  loss: 5.1688 -- time: 14.1882 sec.
# ステップ( 2710 )  loss: 4.8657 -- time: 14.4899 sec.
# ステップ( 2720 )  loss: 4.3973 -- time: 14.4989 sec.
# ステップ( 2730 )  loss: 5.5066 -- time: 14.3454 sec.
# ステップ( 2740 )  loss: 4.4085 -- time: 14.2757 sec.
# ステップ( 2750 )  loss: 5.2672 -- time: 14.2658 sec.
# ステップ( 2760 )  loss: 4.7854 -- time: 14.3104 sec.
# ステップ( 2770 )  loss: 4.7738 -- time: 14.1300 sec.
# ステップ( 2780 )  loss: 4.7150 -- time: 14.5115 sec.
# ステップ( 2790 )  loss: 4.3689 -- time: 14.5743 sec.
# ステップ( 2800 )  loss: 4.7400 -- time: 14.5255 sec.
# ステップ( 2810 )  loss: 4.8488 -- time: 14.3235 sec.
# ステップ( 2820 )  loss: 4.8829 -- time: 14.4491 sec.
# ステップ( 2830 )  loss: 4.2386 -- time: 14.0784 sec.
# ステップ( 2840 )  loss: 4.6770 -- time: 14.4623 sec.
# ステップ( 2850 )  loss: 5.0487 -- time: 14.3736 sec.
# ステップ( 2860 )  loss: 4.5012 -- time: 14.1082 sec.
# ---------------------------------------
# train_loss: 874.5786 - val_loss(Every 10 epochs): 0.0000
# time:  267.3856 sec.
# ---------------------------------------
# Epoch 17/50
# ---------------------------------------
# ステップ( 2870 )  loss: 4.6544 -- time: 8.4196 sec.
# ステップ( 2880 )  loss: 5.1230 -- time: 14.3115 sec.
# ステップ( 2890 )  loss: 4.2861 -- time: 14.4159 sec.
# ステップ( 2900 )  loss: 4.7193 -- time: 14.6583 sec.
# ステップ( 2910 )  loss: 5.0434 -- time: 14.4476 sec.
# ステップ( 2920 )  loss: 4.8662 -- time: 14.4057 sec.
# ステップ( 2930 )  loss: 4.8239 -- time: 14.3633 sec.
# ステップ( 2940 )  loss: 4.4809 -- time: 14.3530 sec.
# ステップ( 2950 )  loss: 4.6914 -- time: 14.2108 sec.
# ステップ( 2960 )  loss: 5.3073 -- time: 14.3886 sec.
# ステップ( 2970 )  loss: 4.7731 -- time: 14.5486 sec.
# ステップ( 2980 )  loss: 5.0307 -- time: 14.4548 sec.
# ステップ( 2990 )  loss: 4.8234 -- time: 14.2856 sec.
# ステップ( 3000 )  loss: 4.4902 -- time: 14.1036 sec.
# ステップ( 3010 )  loss: 5.4197 -- time: 14.5295 sec.
# ステップ( 3020 )  loss: 4.9188 -- time: 14.1847 sec.
# ステップ( 3030 )  loss: 4.5097 -- time: 14.3895 sec.
# ステップ( 3040 )  loss: 5.0616 -- time: 14.3106 sec.
# ---------------------------------------
# train_loss: 859.6842 - val_loss(Every 10 epochs): 0.0000
# time:  267.8181 sec.
# ---------------------------------------
# Epoch 18/50
# ---------------------------------------
# ステップ( 3050 )  loss: 5.0581 -- time: 10.1116 sec.
# ステップ( 3060 )  loss: 4.7155 -- time: 14.0208 sec.
# ステップ( 3070 )  loss: 4.9426 -- time: 14.6900 sec.
# ステップ( 3080 )  loss: 4.9973 -- time: 14.2769 sec.
# ステップ( 3090 )  loss: 4.1661 -- time: 14.2796 sec.
# ステップ( 3100 )  loss: 4.6276 -- time: 14.1190 sec.
# ステップ( 3110 )  loss: 4.9819 -- time: 14.1974 sec.
# ステップ( 3120 )  loss: 4.6391 -- time: 14.4089 sec.
# ステップ( 3130 )  loss: 4.4154 -- time: 14.3770 sec.
# ステップ( 3140 )  loss: 4.5100 -- time: 14.3091 sec.
# ステップ( 3150 )  loss: 5.1779 -- time: 14.1864 sec.
# ステップ( 3160 )  loss: 5.1887 -- time: 14.4187 sec.
# ステップ( 3170 )  loss: 4.5296 -- time: 14.3212 sec.
# ステップ( 3180 )  loss: 4.6110 -- time: 14.2929 sec.
# ステップ( 3190 )  loss: 4.0502 -- time: 14.2457 sec.
# ステップ( 3200 )  loss: 4.7825 -- time: 14.1542 sec.
# ステップ( 3210 )  loss: 4.9156 -- time: 14.4490 sec.
# ステップ( 3220 )  loss: 4.7078 -- time: 14.3834 sec.
# ---------------------------------------
# train_loss: 851.8868 - val_loss(Every 10 epochs): 0.0000
# time:  266.6629 sec.
# ---------------------------------------
# Epoch 19/50
# ---------------------------------------
# ステップ( 3230 )  loss: 4.7077 -- time: 11.3219 sec.
# ステップ( 3240 )  loss: 4.3648 -- time: 14.1586 sec.
# ステップ( 3250 )  loss: 5.0286 -- time: 14.4393 sec.
# ステップ( 3260 )  loss: 5.1826 -- time: 14.2227 sec.
# ステップ( 3270 )  loss: 4.9695 -- time: 14.6323 sec.
# ステップ( 3280 )  loss: 4.8855 -- time: 14.4563 sec.
# ステップ( 3290 )  loss: 4.6485 -- time: 14.6142 sec.
# ステップ( 3300 )  loss: 5.1582 -- time: 14.3823 sec.
# ステップ( 3310 )  loss: 4.7849 -- time: 14.1793 sec.
# ステップ( 3320 )  loss: 4.6396 -- time: 14.2089 sec.
# ステップ( 3330 )  loss: 4.7472 -- time: 14.2898 sec.
# ステップ( 3340 )  loss: 4.6746 -- time: 14.0341 sec.
# ステップ( 3350 )  loss: 5.1046 -- time: 14.1770 sec.
# ステップ( 3360 )  loss: 4.8175 -- time: 14.2114 sec.
# ステップ( 3370 )  loss: 4.8569 -- time: 14.3934 sec.
# ステップ( 3380 )  loss: 4.3935 -- time: 14.4680 sec.
# ステップ( 3390 )  loss: 4.3694 -- time: 14.4880 sec.
# ステップ( 3400 )  loss: 4.3185 -- time: 14.3501 sec.
# ---------------------------------------
# train_loss: 837.4637 - val_loss(Every 10 epochs): 0.0000
# time:  266.8769 sec.
# ---------------------------------------
# Epoch 20/50
# ---------------------------------------
# ステップ( 3410 )  loss: 4.8437 -- time: 12.8112 sec.
# ステップ( 3420 )  loss: 4.7920 -- time: 14.4287 sec.
# ステップ( 3430 )  loss: 4.6300 -- time: 14.1932 sec.
# ステップ( 3440 )  loss: 4.4382 -- time: 14.2285 sec.
# ステップ( 3450 )  loss: 4.5249 -- time: 14.1169 sec.
# ステップ( 3460 )  loss: 4.6417 -- time: 14.3637 sec.
# ステップ( 3470 )  loss: 4.5944 -- time: 14.3693 sec.
# ステップ( 3480 )  loss: 4.3841 -- time: 14.3106 sec.
# ステップ( 3490 )  loss: 4.3155 -- time: 14.2363 sec.
# ステップ( 3500 )  loss: 4.8843 -- time: 14.6284 sec.
# ステップ( 3510 )  loss: 4.4415 -- time: 14.3113 sec.
# ステップ( 3520 )  loss: 4.5176 -- time: 14.3980 sec.
# ステップ( 3530 )  loss: 4.0464 -- time: 14.3457 sec.
# ステップ( 3540 )  loss: 4.6986 -- time: 14.2906 sec.
# ステップ( 3550 )  loss: 4.6875 -- time: 14.6110 sec.
# ステップ( 3560 )  loss: 4.4027 -- time: 14.6003 sec.
# ステップ( 3570 )  loss: 4.6035 -- time: 14.4414 sec.
# ステップ( 3580 )  loss: 4.7121 -- time: 13.9459 sec.
# ---------------------------------------
# （validation）
# ---------------------------------------
# train_loss: 822.4069 - val_loss(Every 10 epochs): 831.8897
# time:  372.0843 sec.
# --saved weights--
# ---------------------------------------
# Epoch 21/50
# ---------------------------------------
# ステップ( 3590 )  loss: 4.4433 -- time: 14.5934 sec.
# ステップ( 3600 )  loss: 4.1432 -- time: 14.4610 sec.
# ステップ( 3610 )  loss: 4.7794 -- time: 14.1326 sec.
# ステップ( 3620 )  loss: 4.5411 -- time: 14.4577 sec.
# ステップ( 3630 )  loss: 4.2629 -- time: 14.3031 sec.
# ステップ( 3640 )  loss: 3.9230 -- time: 14.4263 sec.
# ステップ( 3650 )  loss: 4.5091 -- time: 14.5117 sec.
# ステップ( 3660 )  loss: 4.5915 -- time: 14.2962 sec.
# ステップ( 3670 )  loss: 4.7403 -- time: 14.5075 sec.
# ステップ( 3680 )  loss: 4.7248 -- time: 14.2471 sec.
# ステップ( 3690 )  loss: 4.6813 -- time: 14.5084 sec.
# ステップ( 3700 )  loss: 4.3586 -- time: 14.4245 sec.
# ステップ( 3710 )  loss: 4.5216 -- time: 14.2694 sec.
# ステップ( 3720 )  loss: 4.2799 -- time: 14.4321 sec.
# ステップ( 3730 )  loss: 4.3579 -- time: 14.2481 sec.
# ステップ( 3740 )  loss: 5.1953 -- time: 14.3699 sec.
# ステップ( 3750 )  loss: 4.8763 -- time: 14.1756 sec.
# ---------------------------------------
# train_loss: 810.2750 - val_loss(Every 10 epochs): 0.0000
# time:  267.4366 sec.
# ---------------------------------------
# Epoch 22/50
# ---------------------------------------
# ステップ( 3760 )  loss: 4.5254 -- time: 0.8293 sec.
# ステップ( 3770 )  loss: 4.8923 -- time: 14.2813 sec.
# ステップ( 3780 )  loss: 4.7674 -- time: 14.4585 sec.
# ステップ( 3790 )  loss: 4.4580 -- time: 14.0700 sec.
# ステップ( 3800 )  loss: 4.4593 -- time: 14.3941 sec.
# ステップ( 3810 )  loss: 4.6017 -- time: 14.2099 sec.
# ステップ( 3820 )  loss: 4.3048 -- time: 14.3543 sec.
# ステップ( 3830 )  loss: 4.8027 -- time: 14.2749 sec.
# ステップ( 3840 )  loss: 4.7698 -- time: 14.3490 sec.
# ステップ( 3850 )  loss: 3.9319 -- time: 14.2492 sec.
# ステップ( 3860 )  loss: 4.5357 -- time: 14.3947 sec.
# ステップ( 3870 )  loss: 4.1945 -- time: 14.1845 sec.
# ステップ( 3880 )  loss: 4.5591 -- time: 14.2477 sec.
# ステップ( 3890 )  loss: 4.9244 -- time: 14.5489 sec.
# ステップ( 3900 )  loss: 4.3910 -- time: 13.8668 sec.
# ステップ( 3910 )  loss: 3.9905 -- time: 14.3641 sec.
# ステップ( 3920 )  loss: 4.4072 -- time: 14.2738 sec.
# ステップ( 3930 )  loss: 4.3477 -- time: 14.5398 sec.
# ---------------------------------------
# train_loss: 799.3586 - val_loss(Every 10 epochs): 0.0000
# time:  266.2390 sec.
# ---------------------------------------
# Epoch 23/50
# ---------------------------------------
# ステップ( 3940 )  loss: 4.4911 -- time: 2.3737 sec.
# ステップ( 3950 )  loss: 4.0286 -- time: 14.3236 sec.
# ステップ( 3960 )  loss: 4.2229 -- time: 14.2661 sec.
# ステップ( 3970 )  loss: 4.6539 -- time: 14.5251 sec.
# ステップ( 3980 )  loss: 4.4843 -- time: 14.1032 sec.
# ステップ( 3990 )  loss: 4.4593 -- time: 14.3172 sec.
# ステップ( 4000 )  loss: 4.2908 -- time: 14.4526 sec.
# ステップ( 4010 )  loss: 4.2287 -- time: 14.3122 sec.
# ステップ( 4020 )  loss: 4.7420 -- time: 14.4618 sec.
# ステップ( 4030 )  loss: 4.5812 -- time: 14.5164 sec.
# ステップ( 4040 )  loss: 4.4772 -- time: 14.3333 sec.
# ステップ( 4050 )  loss: 4.3592 -- time: 14.3451 sec.
# ステップ( 4060 )  loss: 4.8809 -- time: 14.2146 sec.
# ステップ( 4070 )  loss: 4.2701 -- time: 14.2641 sec.
# ステップ( 4080 )  loss: 4.2547 -- time: 14.1963 sec.
# ステップ( 4090 )  loss: 4.1737 -- time: 14.0266 sec.
# ステップ( 4100 )  loss: 4.0953 -- time: 14.2295 sec.
# ステップ( 4110 )  loss: 4.5527 -- time: 14.2232 sec.
# ---------------------------------------
# train_loss: 786.4983 - val_loss(Every 10 epochs): 0.0000
# time:  266.7489 sec.
# ---------------------------------------
# Epoch 24/50
# ---------------------------------------
# ステップ( 4120 )  loss: 4.6790 -- time: 3.9779 sec.
# ステップ( 4130 )  loss: 4.0403 -- time: 14.7363 sec.
# ステップ( 4140 )  loss: 4.7874 -- time: 14.4919 sec.
# ステップ( 4150 )  loss: 4.6832 -- time: 14.2089 sec.
# ステップ( 4160 )  loss: 3.9503 -- time: 14.3530 sec.
# ステップ( 4170 )  loss: 4.1246 -- time: 14.3271 sec.
# ステップ( 4180 )  loss: 4.3723 -- time: 14.3433 sec.
# ステップ( 4190 )  loss: 4.1978 -- time: 14.1440 sec.
# ステップ( 4200 )  loss: 3.9343 -- time: 14.1898 sec.
# ステップ( 4210 )  loss: 4.6070 -- time: 14.4513 sec.
# ステップ( 4220 )  loss: 3.9134 -- time: 14.0769 sec.
# ステップ( 4230 )  loss: 4.3238 -- time: 14.4477 sec.
# ステップ( 4240 )  loss: 4.5261 -- time: 14.5555 sec.
# ステップ( 4250 )  loss: 4.5266 -- time: 14.4487 sec.
# ステップ( 4260 )  loss: 4.3741 -- time: 14.2511 sec.
# ステップ( 4270 )  loss: 4.0162 -- time: 14.3254 sec.
# ステップ( 4280 )  loss: 4.3551 -- time: 14.3053 sec.
# ステップ( 4290 )  loss: 4.4185 -- time: 14.4378 sec.
# ---------------------------------------
# train_loss: 776.0729 - val_loss(Every 10 epochs): 0.0000
# time:  267.5614 sec.
# ---------------------------------------
# Epoch 25/50
# ---------------------------------------
# ステップ( 4300 )  loss: 4.1446 -- time: 5.5335 sec.
# ステップ( 4310 )  loss: 4.1693 -- time: 14.4265 sec.
# ステップ( 4320 )  loss: 3.9233 -- time: 14.4145 sec.
# ステップ( 4330 )  loss: 3.9900 -- time: 14.5988 sec.
# ステップ( 4340 )  loss: 4.0965 -- time: 14.2535 sec.
# ステップ( 4350 )  loss: 4.2266 -- time: 14.0505 sec.
# ステップ( 4360 )  loss: 4.4278 -- time: 14.4356 sec.
# ステップ( 4370 )  loss: 4.5442 -- time: 14.4626 sec.
# ステップ( 4380 )  loss: 4.5464 -- time: 14.7901 sec.
# ステップ( 4390 )  loss: 4.2615 -- time: 14.5200 sec.
# ステップ( 4400 )  loss: 4.0931 -- time: 14.5164 sec.
# ステップ( 4410 )  loss: 4.3339 -- time: 14.3725 sec.
# ステップ( 4420 )  loss: 4.1065 -- time: 14.5439 sec.
# ステップ( 4430 )  loss: 4.6731 -- time: 14.6615 sec.
# ステップ( 4440 )  loss: 4.0708 -- time: 14.2716 sec.
# ステップ( 4450 )  loss: 4.4964 -- time: 14.3960 sec.
# ステップ( 4460 )  loss: 4.3469 -- time: 14.4839 sec.
# ステップ( 4470 )  loss: 4.1961 -- time: 14.1216 sec.
# ---------------------------------------
# train_loss: 767.9276 - val_loss(Every 10 epochs): 0.0000
# time:  268.6729 sec.
# ---------------------------------------
# Epoch 26/50
# ---------------------------------------
# ステップ( 4480 )  loss: 3.6097 -- time: 7.0021 sec.
# ステップ( 4490 )  loss: 4.2943 -- time: 14.3415 sec.
# ステップ( 4500 )  loss: 4.2907 -- time: 14.2443 sec.
# ステップ( 4510 )  loss: 4.0265 -- time: 14.2486 sec.
# ステップ( 4520 )  loss: 3.8659 -- time: 14.4085 sec.
# ステップ( 4530 )  loss: 4.5679 -- time: 14.3142 sec.
# ステップ( 4540 )  loss: 4.4991 -- time: 14.2499 sec.
# ステップ( 4550 )  loss: 3.8754 -- time: 14.2528 sec.
# ステップ( 4560 )  loss: 4.2265 -- time: 14.1244 sec.
# ステップ( 4570 )  loss: 4.1624 -- time: 14.1915 sec.
# ステップ( 4580 )  loss: 4.2093 -- time: 14.3257 sec.
# ステップ( 4590 )  loss: 4.2747 -- time: 14.4411 sec.
# ステップ( 4600 )  loss: 4.3315 -- time: 14.4342 sec.
# ステップ( 4610 )  loss: 4.0738 -- time: 14.3951 sec.
# ステップ( 4620 )  loss: 4.0600 -- time: 14.3120 sec.
# ステップ( 4630 )  loss: 3.6759 -- time: 14.5296 sec.
# ステップ( 4640 )  loss: 4.1768 -- time: 14.3674 sec.
# ステップ( 4650 )  loss: 3.9172 -- time: 14.0595 sec.
# ---------------------------------------
# train_loss: 764.6778 - val_loss(Every 10 epochs): 0.0000
# time:  266.7946 sec.
# ---------------------------------------
# Epoch 27/50
# ---------------------------------------
# ステップ( 4660 )  loss: 3.4042 -- time: 8.3936 sec.
# ステップ( 4670 )  loss: 4.9911 -- time: 14.7103 sec.
# ステップ( 4680 )  loss: 3.8380 -- time: 13.9476 sec.
# ステップ( 4690 )  loss: 4.7192 -- time: 14.3816 sec.
# ステップ( 4700 )  loss: 4.3935 -- time: 14.3374 sec.
# ステップ( 4710 )  loss: 5.2187 -- time: 14.3584 sec.
# ステップ( 4720 )  loss: 4.2540 -- time: 14.2790 sec.
# ステップ( 4730 )  loss: 4.3723 -- time: 14.3752 sec.
# ステップ( 4740 )  loss: 3.9732 -- time: 14.4965 sec.
# ステップ( 4750 )  loss: 3.6873 -- time: 14.2426 sec.
# ステップ( 4760 )  loss: 4.2128 -- time: 14.3898 sec.
# ステップ( 4770 )  loss: 3.8138 -- time: 14.6588 sec.
# ステップ( 4780 )  loss: 4.3436 -- time: 14.2745 sec.
# ステップ( 4790 )  loss: 5.0180 -- time: 14.1681 sec.
# ステップ( 4800 )  loss: 4.4294 -- time: 14.2518 sec.
# ステップ( 4810 )  loss: 4.1510 -- time: 14.4594 sec.
# ステップ( 4820 )  loss: 4.4955 -- time: 14.5400 sec.
# ステップ( 4830 )  loss: 4.4933 -- time: 14.7390 sec.
# ---------------------------------------
# train_loss: 755.1063 - val_loss(Every 10 epochs): 0.0000
# time:  267.9983 sec.
# ---------------------------------------
# Epoch 28/50
# ---------------------------------------
# ステップ( 4840 )  loss: 3.5929 -- time: 10.0173 sec.
# ステップ( 4850 )  loss: 4.0394 -- time: 14.3516 sec.
# ステップ( 4860 )  loss: 4.2232 -- time: 14.2018 sec.
# ステップ( 4870 )  loss: 4.5222 -- time: 14.3675 sec.
# ステップ( 4880 )  loss: 4.2194 -- time: 14.2812 sec.
# ステップ( 4890 )  loss: 4.1465 -- time: 14.1718 sec.
# ステップ( 4900 )  loss: 4.0643 -- time: 14.1762 sec.
# ステップ( 4910 )  loss: 4.1925 -- time: 14.3181 sec.
# ステップ( 4920 )  loss: 4.0287 -- time: 14.4044 sec.
# ステップ( 4930 )  loss: 3.7192 -- time: 14.2053 sec.
# ステップ( 4940 )  loss: 4.4210 -- time: 14.3196 sec.
# ステップ( 4950 )  loss: 3.7373 -- time: 14.1958 sec.
# ステップ( 4960 )  loss: 4.0511 -- time: 14.6651 sec.
# ステップ( 4970 )  loss: 3.7866 -- time: 14.4222 sec.
# ステップ( 4980 )  loss: 4.1570 -- time: 14.4484 sec.
# ステップ( 4990 )  loss: 4.4930 -- time: 14.1147 sec.
# ステップ( 5000 )  loss: 4.1335 -- time: 14.5032 sec.
# ステップ( 5010 )  loss: 4.3815 -- time: 14.4052 sec.
# ---------------------------------------
# train_loss: 746.0714 - val_loss(Every 10 epochs): 0.0000
# time:  266.9915 sec.
# ---------------------------------------
# Epoch 29/50
# ---------------------------------------
# ステップ( 5020 )  loss: 3.8659 -- time: 11.4198 sec.
# ステップ( 5030 )  loss: 3.8665 -- time: 14.3141 sec.
# ステップ( 5040 )  loss: 4.1889 -- time: 14.4768 sec.
# ステップ( 5050 )  loss: 3.8037 -- time: 14.6868 sec.
# ステップ( 5060 )  loss: 4.3797 -- time: 14.3801 sec.
# ステップ( 5070 )  loss: 3.8759 -- time: 14.3688 sec.
# ステップ( 5080 )  loss: 4.1724 -- time: 14.2185 sec.
# ステップ( 5090 )  loss: 4.3354 -- time: 14.3023 sec.
# ステップ( 5100 )  loss: 3.5711 -- time: 14.3059 sec.
# ステップ( 5110 )  loss: 4.2538 -- time: 14.0921 sec.
# ステップ( 5120 )  loss: 4.5729 -- time: 14.1661 sec.
# ステップ( 5130 )  loss: 4.4382 -- time: 14.3617 sec.
# ステップ( 5140 )  loss: 4.1898 -- time: 14.4274 sec.
# ステップ( 5150 )  loss: 3.8369 -- time: 14.3565 sec.
# ステップ( 5160 )  loss: 3.5351 -- time: 14.0331 sec.
# ステップ( 5170 )  loss: 4.3456 -- time: 14.1806 sec.
# ステップ( 5180 )  loss: 3.5097 -- time: 14.6032 sec.
# ステップ( 5190 )  loss: 4.1214 -- time: 14.1491 sec.
# ---------------------------------------
# train_loss: 734.2286 - val_loss(Every 10 epochs): 0.0000
# time:  266.7509 sec.
# ---------------------------------------
# Epoch 30/50
# ---------------------------------------
# ステップ( 5200 )  loss: 3.9860 -- time: 12.8524 sec.
# ステップ( 5210 )  loss: 3.8919 -- time: 14.4487 sec.
# ステップ( 5220 )  loss: 4.2712 -- time: 14.2285 sec.
# ステップ( 5230 )  loss: 4.0594 -- time: 14.1166 sec.
# ステップ( 5240 )  loss: 4.5737 -- time: 14.4473 sec.
# ステップ( 5250 )  loss: 4.0863 -- time: 14.2157 sec.
# ステップ( 5260 )  loss: 4.0565 -- time: 14.5297 sec.
# ステップ( 5270 )  loss: 3.6546 -- time: 14.2159 sec.
# ステップ( 5280 )  loss: 4.3684 -- time: 14.5307 sec.
# ステップ( 5290 )  loss: 4.1606 -- time: 14.2367 sec.
# ステップ( 5300 )  loss: 3.7533 -- time: 14.4570 sec.
# ステップ( 5310 )  loss: 3.9561 -- time: 14.2959 sec.
# ステップ( 5320 )  loss: 4.4926 -- time: 14.2767 sec.
# ステップ( 5330 )  loss: 3.9685 -- time: 14.4041 sec.
# ステップ( 5340 )  loss: 4.1167 -- time: 14.2118 sec.
# ステップ( 5350 )  loss: 4.7178 -- time: 14.3168 sec.
# ステップ( 5360 )  loss: 4.3233 -- time: 14.2525 sec.
# ステップ( 5370 )  loss: 4.3526 -- time: 14.2405 sec.
# ---------------------------------------
# （validation）
# ---------------------------------------
# train_loss: 733.2398 - val_loss(Every 10 epochs): 755.5800
# time:  371.6598 sec.
# --saved weights--
# ---------------------------------------
# Epoch 31/50
# ---------------------------------------
# ステップ( 5380 )  loss: 4.1546 -- time: 14.1317 sec.
# ステップ( 5390 )  loss: 3.8966 -- time: 14.4899 sec.
# ステップ( 5400 )  loss: 4.7365 -- time: 14.1829 sec.
# ステップ( 5410 )  loss: 3.8530 -- time: 14.2790 sec.
# ステップ( 5420 )  loss: 3.8950 -- time: 14.2312 sec.
# ステップ( 5430 )  loss: 4.0614 -- time: 14.3262 sec.
# ステップ( 5440 )  loss: 3.7371 -- time: 14.3245 sec.
# ステップ( 5450 )  loss: 3.8172 -- time: 14.2951 sec.
# ステップ( 5460 )  loss: 4.1789 -- time: 13.9743 sec.
# ステップ( 5470 )  loss: 3.8990 -- time: 14.5113 sec.
# ステップ( 5480 )  loss: 4.2731 -- time: 14.0409 sec.
# ステップ( 5490 )  loss: 4.6387 -- time: 14.3543 sec.
# ステップ( 5500 )  loss: 3.7864 -- time: 14.2143 sec.
# ステップ( 5510 )  loss: 3.8477 -- time: 14.5411 sec.
# ステップ( 5520 )  loss: 4.2358 -- time: 14.4088 sec.
# ステップ( 5530 )  loss: 4.0891 -- time: 14.2178 sec.
# ステップ( 5540 )  loss: 3.7149 -- time: 14.3118 sec.
# ---------------------------------------
# train_loss: 720.5474 - val_loss(Every 10 epochs): 0.0000
# time:  266.0249 sec.
# ---------------------------------------
# Epoch 32/50
# ---------------------------------------
# ステップ( 5550 )  loss: 3.6478 -- time: 0.8229 sec.
# ステップ( 5560 )  loss: 4.0863 -- time: 14.5209 sec.
# ステップ( 5570 )  loss: 3.8209 -- time: 14.2517 sec.
# ステップ( 5580 )  loss: 4.0487 -- time: 14.2355 sec.
# ステップ( 5590 )  loss: 3.9236 -- time: 14.4148 sec.
# ステップ( 5600 )  loss: 3.9530 -- time: 14.4923 sec.
# ステップ( 5610 )  loss: 4.1310 -- time: 14.2764 sec.
# ステップ( 5620 )  loss: 3.5491 -- time: 14.1023 sec.
# ステップ( 5630 )  loss: 3.7757 -- time: 14.4479 sec.
# ステップ( 5640 )  loss: 4.6555 -- time: 14.2166 sec.
# ステップ( 5650 )  loss: 4.2429 -- time: 14.3117 sec.
# ステップ( 5660 )  loss: 4.3019 -- time: 14.0480 sec.
# ステップ( 5670 )  loss: 3.4701 -- time: 14.1698 sec.
# ステップ( 5680 )  loss: 4.4950 -- time: 14.4297 sec.
# ステップ( 5690 )  loss: 4.5253 -- time: 14.3325 sec.
# ステップ( 5700 )  loss: 3.8610 -- time: 14.2359 sec.
# ステップ( 5710 )  loss: 4.1441 -- time: 14.2047 sec.
# ステップ( 5720 )  loss: 4.5728 -- time: 14.4070 sec.
# ---------------------------------------
# train_loss: 715.9021 - val_loss(Every 10 epochs): 0.0000
# time:  266.3817 sec.
# ---------------------------------------
# Epoch 33/50
# ---------------------------------------
# ステップ( 5730 )  loss: 3.3588 -- time: 2.3426 sec.
# ステップ( 5740 )  loss: 3.9501 -- time: 14.1950 sec.
# ステップ( 5750 )  loss: 3.9477 -- time: 14.2306 sec.
# ステップ( 5760 )  loss: 4.2861 -- time: 14.2704 sec.
# ステップ( 5770 )  loss: 3.4344 -- time: 14.4568 sec.
# ステップ( 5780 )  loss: 4.2863 -- time: 14.0744 sec.
# ステップ( 5790 )  loss: 4.1404 -- time: 14.2997 sec.
# ステップ( 5800 )  loss: 3.9888 -- time: 14.1370 sec.
# ステップ( 5810 )  loss: 3.7089 -- time: 14.2266 sec.
# ステップ( 5820 )  loss: 4.3203 -- time: 14.2778 sec.
# ステップ( 5830 )  loss: 3.5025 -- time: 14.1359 sec.
# ステップ( 5840 )  loss: 3.8686 -- time: 14.4169 sec.
# ステップ( 5850 )  loss: 3.8177 -- time: 14.0749 sec.
# ステップ( 5860 )  loss: 4.0107 -- time: 14.5438 sec.
# ステップ( 5870 )  loss: 3.8912 -- time: 14.4545 sec.
# ステップ( 5880 )  loss: 4.3154 -- time: 14.2150 sec.
# ステップ( 5890 )  loss: 3.4127 -- time: 14.0693 sec.
# ステップ( 5900 )  loss: 3.8702 -- time: 14.2678 sec.
# ---------------------------------------
# train_loss: 712.2986 - val_loss(Every 10 epochs): 0.0000
# time:  265.4486 sec.
# ---------------------------------------
# Epoch 34/50
# ---------------------------------------
# ステップ( 5910 )  loss: 4.1186 -- time: 3.8999 sec.
# ステップ( 5920 )  loss: 4.0235 -- time: 14.2174 sec.
# ステップ( 5930 )  loss: 3.9280 -- time: 14.0840 sec.
# ステップ( 5940 )  loss: 4.1752 -- time: 14.3266 sec.
# ステップ( 5950 )  loss: 3.7383 -- time: 14.0758 sec.
# ステップ( 5960 )  loss: 4.4477 -- time: 14.6183 sec.
# ステップ( 5970 )  loss: 3.8184 -- time: 14.5609 sec.
# ステップ( 5980 )  loss: 3.4641 -- time: 14.1351 sec.
# ステップ( 5990 )  loss: 3.8441 -- time: 14.3204 sec.
# ステップ( 6000 )  loss: 4.3471 -- time: 14.4241 sec.
# ステップ( 6010 )  loss: 3.7157 -- time: 14.1659 sec.
# ステップ( 6020 )  loss: 3.4095 -- time: 14.3622 sec.
# ステップ( 6030 )  loss: 4.2827 -- time: 14.1350 sec.
# ステップ( 6040 )  loss: 4.1710 -- time: 14.4197 sec.
# ステップ( 6050 )  loss: 4.1504 -- time: 13.9054 sec.
# ステップ( 6060 )  loss: 3.7335 -- time: 14.4959 sec.
# ステップ( 6070 )  loss: 3.3923 -- time: 14.2308 sec.
# ステップ( 6080 )  loss: 3.9596 -- time: 14.2776 sec.
# ---------------------------------------
# train_loss: 703.9740 - val_loss(Every 10 epochs): 0.0000
# time:  265.9313 sec.
# ---------------------------------------
# Epoch 35/50
# ---------------------------------------
# ステップ( 6090 )  loss: 4.0535 -- time: 5.3890 sec.
# ステップ( 6100 )  loss: 3.8030 -- time: 14.0897 sec.
# ステップ( 6110 )  loss: 3.7663 -- time: 14.2223 sec.
# ステップ( 6120 )  loss: 4.3782 -- time: 14.4243 sec.
# ステップ( 6130 )  loss: 3.9335 -- time: 14.4505 sec.
# ステップ( 6140 )  loss: 3.8381 -- time: 14.2469 sec.
# ステップ( 6150 )  loss: 4.4755 -- time: 14.2171 sec.
# ステップ( 6160 )  loss: 3.3708 -- time: 14.3113 sec.
# ステップ( 6170 )  loss: 3.4576 -- time: 14.0331 sec.
# ステップ( 6180 )  loss: 3.5718 -- time: 14.5721 sec.
# ステップ( 6190 )  loss: 3.5124 -- time: 14.2126 sec.
# ステップ( 6200 )  loss: 3.6380 -- time: 14.3479 sec.
# ステップ( 6210 )  loss: 4.6213 -- time: 13.9058 sec.
# ステップ( 6220 )  loss: 3.5505 -- time: 14.4518 sec.
# ステップ( 6230 )  loss: 3.7666 -- time: 14.3940 sec.
# ステップ( 6240 )  loss: 4.0908 -- time: 14.0141 sec.
# ステップ( 6250 )  loss: 3.3423 -- time: 14.0699 sec.
# ステップ( 6260 )  loss: 4.0951 -- time: 14.3101 sec.
# ---------------------------------------
# train_loss: 691.2520 - val_loss(Every 10 epochs): 0.0000
# time:  265.6077 sec.
# ---------------------------------------
# Epoch 36/50
# ---------------------------------------
# ステップ( 6270 )  loss: 3.8701 -- time: 6.8337 sec.
# ステップ( 6280 )  loss: 4.5245 -- time: 14.2815 sec.
# ステップ( 6290 )  loss: 3.4915 -- time: 14.1780 sec.
# ステップ( 6300 )  loss: 3.6485 -- time: 14.2884 sec.
# ステップ( 6310 )  loss: 3.8050 -- time: 14.3674 sec.
# ステップ( 6320 )  loss: 3.8135 -- time: 14.2902 sec.
# ステップ( 6330 )  loss: 4.0282 -- time: 14.2282 sec.
# ステップ( 6340 )  loss: 4.1259 -- time: 14.3869 sec.
# ステップ( 6350 )  loss: 3.4777 -- time: 14.6000 sec.
# ステップ( 6360 )  loss: 3.7986 -- time: 14.1890 sec.
# ステップ( 6370 )  loss: 3.6542 -- time: 14.0292 sec.
# ステップ( 6380 )  loss: 3.6463 -- time: 14.2415 sec.
# ステップ( 6390 )  loss: 3.6041 -- time: 14.1300 sec.
# ステップ( 6400 )  loss: 3.4890 -- time: 13.9939 sec.
# ステップ( 6410 )  loss: 3.8260 -- time: 14.3489 sec.
# ステップ( 6420 )  loss: 4.4170 -- time: 14.2497 sec.
# ステップ( 6430 )  loss: 3.7242 -- time: 14.2587 sec.
# ステップ( 6440 )  loss: 3.6970 -- time: 14.0379 sec.
# ---------------------------------------
# train_loss: 687.0497 - val_loss(Every 10 epochs): 0.0000
# time:  265.3545 sec.
# ---------------------------------------
# Epoch 37/50
# ---------------------------------------
# ステップ( 6450 )  loss: 3.9712 -- time: 8.3258 sec.
# ステップ( 6460 )  loss: 3.5887 -- time: 14.2985 sec.
# ステップ( 6470 )  loss: 4.1463 -- time: 14.4317 sec.
# ステップ( 6480 )  loss: 3.9223 -- time: 14.3356 sec.
# ステップ( 6490 )  loss: 3.9745 -- time: 14.3877 sec.
# ステップ( 6500 )  loss: 3.5932 -- time: 14.1706 sec.
# ステップ( 6510 )  loss: 4.3719 -- time: 14.6045 sec.
# ステップ( 6520 )  loss: 3.8074 -- time: 14.2804 sec.
# ステップ( 6530 )  loss: 3.6789 -- time: 14.1705 sec.
# ステップ( 6540 )  loss: 3.9449 -- time: 14.5564 sec.
# ステップ( 6550 )  loss: 4.1996 -- time: 14.4195 sec.
# ステップ( 6560 )  loss: 3.8594 -- time: 14.2641 sec.
# ステップ( 6570 )  loss: 3.2718 -- time: 14.2504 sec.
# ステップ( 6580 )  loss: 3.7873 -- time: 14.3248 sec.
# ステップ( 6590 )  loss: 3.1328 -- time: 14.2334 sec.
# ステップ( 6600 )  loss: 3.4158 -- time: 14.1800 sec.
# ステップ( 6610 )  loss: 4.1112 -- time: 14.0659 sec.
# ステップ( 6620 )  loss: 4.2493 -- time: 14.3768 sec.
# ---------------------------------------
# train_loss: 684.0467 - val_loss(Every 10 epochs): 0.0000
# time:  266.7100 sec.
# ---------------------------------------
# Epoch 38/50
# ---------------------------------------
# ステップ( 6630 )  loss: 3.8182 -- time: 10.1181 sec.
# ステップ( 6640 )  loss: 3.9295 -- time: 14.2365 sec.
# ステップ( 6650 )  loss: 4.0058 -- time: 14.3376 sec.
# ステップ( 6660 )  loss: 3.8036 -- time: 14.1019 sec.
# ステップ( 6670 )  loss: 4.2242 -- time: 14.7217 sec.
# ステップ( 6680 )  loss: 3.7107 -- time: 14.4631 sec.
# ステップ( 6690 )  loss: 3.8954 -- time: 14.1844 sec.
# ステップ( 6700 )  loss: 3.7111 -- time: 14.1611 sec.
# ステップ( 6710 )  loss: 3.7534 -- time: 14.4509 sec.
# ステップ( 6720 )  loss: 4.3963 -- time: 13.8788 sec.
# ステップ( 6730 )  loss: 4.3402 -- time: 14.3833 sec.
# ステップ( 6740 )  loss: 3.3906 -- time: 14.4128 sec.
# ステップ( 6750 )  loss: 3.4615 -- time: 14.1056 sec.
# ステップ( 6760 )  loss: 3.1778 -- time: 14.1845 sec.
# ステップ( 6770 )  loss: 3.7023 -- time: 14.2657 sec.
# ステップ( 6780 )  loss: 3.3043 -- time: 14.2852 sec.
# ステップ( 6790 )  loss: 3.9200 -- time: 14.2529 sec.
# ステップ( 6800 )  loss: 3.5442 -- time: 14.3970 sec.
# ---------------------------------------
# train_loss: 682.0025 - val_loss(Every 10 epochs): 0.0000
# time:  266.2625 sec.
# ---------------------------------------
# Epoch 39/50
# ---------------------------------------
# ステップ( 6810 )  loss: 3.7176 -- time: 11.3656 sec.
# ステップ( 6820 )  loss: 3.9372 -- time: 14.3810 sec.
# ステップ( 6830 )  loss: 3.3742 -- time: 14.6241 sec.
# ステップ( 6840 )  loss: 4.0953 -- time: 14.1188 sec.
# ステップ( 6850 )  loss: 4.0118 -- time: 14.1271 sec.
# ステップ( 6860 )  loss: 3.2177 -- time: 14.3167 sec.
# ステップ( 6870 )  loss: 3.5601 -- time: 14.4467 sec.
# ステップ( 6880 )  loss: 3.5979 -- time: 14.2803 sec.
# ステップ( 6890 )  loss: 3.5485 -- time: 14.3707 sec.
# ステップ( 6900 )  loss: 4.1936 -- time: 14.1733 sec.
# ステップ( 6910 )  loss: 3.8331 -- time: 14.4950 sec.
# ステップ( 6920 )  loss: 3.8154 -- time: 14.2314 sec.
# ステップ( 6930 )  loss: 4.0831 -- time: 13.9822 sec.
# ステップ( 6940 )  loss: 4.0320 -- time: 14.5908 sec.
# ステップ( 6950 )  loss: 3.5804 -- time: 14.3331 sec.
# ステップ( 6960 )  loss: 3.9325 -- time: 14.3142 sec.
# ステップ( 6970 )  loss: 3.6645 -- time: 14.2968 sec.
# ステップ( 6980 )  loss: 3.6209 -- time: 14.2020 sec.
# ---------------------------------------
# train_loss: 675.7457 - val_loss(Every 10 epochs): 0.0000
# time:  266.6156 sec.
# ---------------------------------------
# Epoch 40/50
# ---------------------------------------
# ステップ( 6990 )  loss: 3.8033 -- time: 12.8395 sec.
# ステップ( 7000 )  loss: 3.8039 -- time: 14.4919 sec.
# ステップ( 7010 )  loss: 3.8138 -- time: 14.2186 sec.
# ステップ( 7020 )  loss: 3.4758 -- time: 14.2573 sec.
# ステップ( 7030 )  loss: 3.8851 -- time: 14.2412 sec.
# ステップ( 7040 )  loss: 4.0722 -- time: 14.2709 sec.
# ステップ( 7050 )  loss: 4.1393 -- time: 14.3937 sec.
# ステップ( 7060 )  loss: 3.9838 -- time: 14.2877 sec.
# ステップ( 7070 )  loss: 4.5160 -- time: 14.2798 sec.
# ステップ( 7080 )  loss: 3.4639 -- time: 14.1973 sec.
# ステップ( 7090 )  loss: 4.2108 -- time: 14.4680 sec.
# ステップ( 7100 )  loss: 4.3168 -- time: 14.1925 sec.
# ステップ( 7110 )  loss: 3.9140 -- time: 14.5146 sec.
# ステップ( 7120 )  loss: 4.1350 -- time: 14.3258 sec.
# ステップ( 7130 )  loss: 4.0242 -- time: 14.5365 sec.
# ステップ( 7140 )  loss: 3.1955 -- time: 14.1963 sec.
# ステップ( 7150 )  loss: 3.5529 -- time: 14.2651 sec.
# ステップ( 7160 )  loss: 3.2462 -- time: 13.7863 sec.
# ---------------------------------------
# （validation）
# ---------------------------------------
# train_loss: 671.1498 - val_loss(Every 10 epochs): 717.6039
# time:  370.7964 sec.
# --saved weights--
# ---------------------------------------
# Epoch 41/50
# ---------------------------------------
# ステップ( 7170 )  loss: 3.8816 -- time: 14.3866 sec.
# ステップ( 7180 )  loss: 3.3475 -- time: 14.6114 sec.
# ステップ( 7190 )  loss: 3.6305 -- time: 14.3215 sec.
# ステップ( 7200 )  loss: 3.5438 -- time: 14.3616 sec.
# ステップ( 7210 )  loss: 3.1206 -- time: 14.4769 sec.
# ステップ( 7220 )  loss: 3.6416 -- time: 14.4958 sec.
# ステップ( 7230 )  loss: 3.4903 -- time: 14.3000 sec.
# ステップ( 7240 )  loss: 3.7871 -- time: 14.2610 sec.
# ステップ( 7250 )  loss: 4.1804 -- time: 14.3397 sec.
# ステップ( 7260 )  loss: 3.6562 -- time: 14.1957 sec.
# ステップ( 7270 )  loss: 3.6604 -- time: 14.4315 sec.
# ステップ( 7280 )  loss: 3.8808 -- time: 14.2384 sec.
# ステップ( 7290 )  loss: 3.4932 -- time: 14.2171 sec.
# ステップ( 7300 )  loss: 3.6773 -- time: 14.3665 sec.
# ステップ( 7310 )  loss: 3.9240 -- time: 14.2326 sec.
# ステップ( 7320 )  loss: 3.3414 -- time: 14.1375 sec.
# ステップ( 7330 )  loss: 3.4276 -- time: 14.2385 sec.
# ---------------------------------------
# train_loss: 670.7161 - val_loss(Every 10 epochs): 0.0000
# time:  266.8700 sec.
# ---------------------------------------
# Epoch 42/50
# ---------------------------------------
# ステップ( 7340 )  loss: 3.8973 -- time: 0.9744 sec.
# ステップ( 7350 )  loss: 3.7600 -- time: 14.0370 sec.
# ステップ( 7360 )  loss: 3.5338 -- time: 14.5346 sec.
# ステップ( 7370 )  loss: 4.0198 -- time: 14.4900 sec.
# ステップ( 7380 )  loss: 3.7062 -- time: 14.2680 sec.
# ステップ( 7390 )  loss: 3.2027 -- time: 14.2168 sec.
# ステップ( 7400 )  loss: 4.0966 -- time: 14.4189 sec.
# ステップ( 7410 )  loss: 3.4956 -- time: 14.2636 sec.
# ステップ( 7420 )  loss: 3.9620 -- time: 14.0277 sec.
# ステップ( 7430 )  loss: 3.3407 -- time: 14.3127 sec.
# ステップ( 7440 )  loss: 3.7581 -- time: 14.4815 sec.
# ステップ( 7450 )  loss: 2.8956 -- time: 14.3976 sec.
# ステップ( 7460 )  loss: 4.1173 -- time: 14.4789 sec.
# ステップ( 7470 )  loss: 3.7741 -- time: 14.2589 sec.
# ステップ( 7480 )  loss: 3.8045 -- time: 14.2728 sec.
# ステップ( 7490 )  loss: 3.8134 -- time: 14.0604 sec.
# ステップ( 7500 )  loss: 3.7851 -- time: 14.5546 sec.
# ステップ( 7510 )  loss: 3.6925 -- time: 14.6248 sec.
# ---------------------------------------
# train_loss: 658.3970 - val_loss(Every 10 epochs): 0.0000
# time:  267.1069 sec.
# ---------------------------------------
# Epoch 43/50
# ---------------------------------------
# ステップ( 7520 )  loss: 4.1517 -- time: 2.3733 sec.
# ステップ( 7530 )  loss: 3.0984 -- time: 14.3694 sec.
# ステップ( 7540 )  loss: 3.9691 -- time: 14.3667 sec.
# ステップ( 7550 )  loss: 3.5458 -- time: 14.1758 sec.
# ステップ( 7560 )  loss: 3.9428 -- time: 14.6036 sec.
# ステップ( 7570 )  loss: 4.4138 -- time: 14.4555 sec.
# ステップ( 7580 )  loss: 3.7562 -- time: 14.2801 sec.
# ステップ( 7590 )  loss: 3.8073 -- time: 14.6052 sec.
# ステップ( 7600 )  loss: 3.4593 -- time: 14.1001 sec.
# ステップ( 7610 )  loss: 3.7760 -- time: 14.1562 sec.
# ステップ( 7620 )  loss: 3.6122 -- time: 14.3638 sec.
# ステップ( 7630 )  loss: 3.9972 -- time: 14.2491 sec.
# ステップ( 7640 )  loss: 3.8108 -- time: 14.2031 sec.
# ステップ( 7650 )  loss: 4.0905 -- time: 14.3251 sec.
# ステップ( 7660 )  loss: 3.3440 -- time: 14.1743 sec.
# ステップ( 7670 )  loss: 3.3764 -- time: 14.4017 sec.
# ステップ( 7680 )  loss: 4.3935 -- time: 14.4014 sec.
# ステップ( 7690 )  loss: 3.6912 -- time: 14.1419 sec.
# ---------------------------------------
# train_loss: 661.2924 - val_loss(Every 10 epochs): 0.0000
# time:  266.6817 sec.
# ---------------------------------------
# Epoch 44/50
# ---------------------------------------
# ステップ( 7700 )  loss: 3.5468 -- time: 3.9730 sec.
# ステップ( 7710 )  loss: 3.6460 -- time: 14.3148 sec.
# ステップ( 7720 )  loss: 3.8471 -- time: 14.1494 sec.
# ステップ( 7730 )  loss: 4.1127 -- time: 14.5174 sec.
# ステップ( 7740 )  loss: 3.7084 -- time: 14.6677 sec.
# ステップ( 7750 )  loss: 2.8317 -- time: 14.2629 sec.
# ステップ( 7760 )  loss: 3.9260 -- time: 14.6392 sec.
# ステップ( 7770 )  loss: 3.9126 -- time: 14.2078 sec.
# ステップ( 7780 )  loss: 4.1068 -- time: 14.2590 sec.
# ステップ( 7790 )  loss: 3.3465 -- time: 14.1371 sec.
# ステップ( 7800 )  loss: 3.9323 -- time: 14.5988 sec.
# ステップ( 7810 )  loss: 3.4297 -- time: 14.1338 sec.
# ステップ( 7820 )  loss: 3.2958 -- time: 14.2807 sec.
# ステップ( 7830 )  loss: 3.9775 -- time: 14.4268 sec.
# ステップ( 7840 )  loss: 3.2789 -- time: 14.1496 sec.
# ステップ( 7850 )  loss: 3.2547 -- time: 14.4582 sec.
# ステップ( 7860 )  loss: 3.8128 -- time: 14.2958 sec.
# ステップ( 7870 )  loss: 3.0924 -- time: 14.1191 sec.
# ---------------------------------------
# train_loss: 651.3033 - val_loss(Every 10 epochs): 0.0000
# time:  267.0643 sec.
# ---------------------------------------
# Epoch 45/50
# ---------------------------------------
# ステップ( 7880 )  loss: 3.9648 -- time: 5.3392 sec.
# ステップ( 7890 )  loss: 3.8030 -- time: 14.3690 sec.
# ステップ( 7900 )  loss: 3.5942 -- time: 14.2048 sec.
# ステップ( 7910 )  loss: 3.7216 -- time: 14.1054 sec.
# ステップ( 7920 )  loss: 3.8001 -- time: 14.1849 sec.
# ステップ( 7930 )  loss: 3.5075 -- time: 14.3092 sec.
# ステップ( 7940 )  loss: 3.4439 -- time: 14.1872 sec.
# ステップ( 7950 )  loss: 3.7226 -- time: 14.1957 sec.
# ステップ( 7960 )  loss: 3.5801 -- time: 14.5043 sec.
# ステップ( 7970 )  loss: 3.6489 -- time: 14.3693 sec.
# ステップ( 7980 )  loss: 3.4730 -- time: 14.1480 sec.
# ステップ( 7990 )  loss: 3.5424 -- time: 14.3034 sec.
# ステップ( 8000 )  loss: 3.5321 -- time: 13.9852 sec.
# ステップ( 8010 )  loss: 3.6734 -- time: 14.3036 sec.
# ステップ( 8020 )  loss: 3.7221 -- time: 14.1670 sec.
# ステップ( 8030 )  loss: 3.1847 -- time: 14.0205 sec.
# ステップ( 8040 )  loss: 3.7430 -- time: 14.4548 sec.
# ステップ( 8050 )  loss: 3.5140 -- time: 14.2184 sec.
# ---------------------------------------
# train_loss: 643.7363 - val_loss(Every 10 epochs): 0.0000
# time:  265.3239 sec.
# ---------------------------------------
# Epoch 46/50
# ---------------------------------------
# ステップ( 8060 )  loss: 4.2422 -- time: 6.8340 sec.
# ステップ( 8070 )  loss: 3.8992 -- time: 14.1852 sec.
# ステップ( 8080 )  loss: 3.6818 -- time: 13.9358 sec.
# ステップ( 8090 )  loss: 3.6437 -- time: 14.1105 sec.
# ステップ( 8100 )  loss: 3.7295 -- time: 14.0509 sec.
# ステップ( 8110 )  loss: 3.3929 -- time: 14.5468 sec.
# ステップ( 8120 )  loss: 4.0474 -- time: 14.0600 sec.
# ステップ( 8130 )  loss: 3.9833 -- time: 14.3337 sec.
# ステップ( 8140 )  loss: 3.8318 -- time: 14.1556 sec.
# ステップ( 8150 )  loss: 4.2017 -- time: 14.2918 sec.
# ステップ( 8160 )  loss: 3.4347 -- time: 14.3037 sec.
# ステップ( 8170 )  loss: 3.8185 -- time: 14.1816 sec.
# ステップ( 8180 )  loss: 3.8016 -- time: 14.3367 sec.
# ステップ( 8190 )  loss: 3.6998 -- time: 14.0421 sec.
# ステップ( 8200 )  loss: 3.4164 -- time: 14.1778 sec.
# ステップ( 8210 )  loss: 4.0210 -- time: 14.4745 sec.
# ステップ( 8220 )  loss: 3.3997 -- time: 14.3170 sec.
# ステップ( 8230 )  loss: 3.5221 -- time: 14.3590 sec.
# ---------------------------------------
# train_loss: 647.7659 - val_loss(Every 10 epochs): 0.0000
# time:  265.1266 sec.
# ---------------------------------------
# Epoch 47/50
# ---------------------------------------
# ステップ( 8240 )  loss: 3.4949 -- time: 8.5447 sec.
# ステップ( 8250 )  loss: 3.5418 -- time: 14.1708 sec.
# ステップ( 8260 )  loss: 3.5272 -- time: 14.1051 sec.
# ステップ( 8270 )  loss: 3.6153 -- time: 14.2704 sec.
# ステップ( 8280 )  loss: 3.6464 -- time: 14.0703 sec.
# ステップ( 8290 )  loss: 3.4290 -- time: 14.0238 sec.
# ステップ( 8300 )  loss: 3.7879 -- time: 14.2458 sec.
# ステップ( 8310 )  loss: 3.3381 -- time: 14.2822 sec.
# ステップ( 8320 )  loss: 3.4620 -- time: 14.2325 sec.
# ステップ( 8330 )  loss: 4.1101 -- time: 14.0502 sec.
# ステップ( 8340 )  loss: 2.8203 -- time: 14.0795 sec.
# ステップ( 8350 )  loss: 3.3819 -- time: 14.3186 sec.
# ステップ( 8360 )  loss: 3.6061 -- time: 14.0321 sec.
# ステップ( 8370 )  loss: 3.7128 -- time: 14.4542 sec.
# ステップ( 8380 )  loss: 3.2848 -- time: 14.2503 sec.
# ステップ( 8390 )  loss: 3.7906 -- time: 14.1510 sec.
# ステップ( 8400 )  loss: 3.8655 -- time: 14.2247 sec.
# ステップ( 8410 )  loss: 3.4822 -- time: 14.2877 sec.
# ---------------------------------------
# train_loss: 637.8614 - val_loss(Every 10 epochs): 0.0000
# time:  264.8669 sec.
# ---------------------------------------
# Epoch 48/50
# ---------------------------------------
# ステップ( 8420 )  loss: 3.8439 -- time: 10.0891 sec.
# ステップ( 8430 )  loss: 3.6996 -- time: 14.2557 sec.
# ステップ( 8440 )  loss: 3.8432 -- time: 14.6009 sec.
# ステップ( 8450 )  loss: 3.1976 -- time: 14.1007 sec.
# ステップ( 8460 )  loss: 3.7288 -- time: 14.3112 sec.
# ステップ( 8470 )  loss: 4.2448 -- time: 14.1775 sec.
# ステップ( 8480 )  loss: 3.1138 -- time: 14.2958 sec.
# ステップ( 8490 )  loss: 3.2446 -- time: 14.3099 sec.
# ステップ( 8500 )  loss: 3.5611 -- time: 14.3463 sec.
# ステップ( 8510 )  loss: 3.2049 -- time: 14.2128 sec.
# ステップ( 8520 )  loss: 3.3858 -- time: 14.1210 sec.
# ステップ( 8530 )  loss: 3.6747 -- time: 14.2707 sec.
# ステップ( 8540 )  loss: 3.3800 -- time: 14.1285 sec.
# ステップ( 8550 )  loss: 3.1353 -- time: 14.1015 sec.
# ステップ( 8560 )  loss: 3.7971 -- time: 14.3047 sec.
# ステップ( 8570 )  loss: 3.3822 -- time: 14.1744 sec.
# ステップ( 8580 )  loss: 3.3173 -- time: 14.2080 sec.
# ステップ( 8590 )  loss: 3.3096 -- time: 14.3312 sec.
# ---------------------------------------
# train_loss: 630.2101 - val_loss(Every 10 epochs): 0.0000
# time:  265.8159 sec.
# ---------------------------------------
# Epoch 49/50
# ---------------------------------------
# ステップ( 8600 )  loss: 3.5935 -- time: 11.3551 sec.
# ステップ( 8610 )  loss: 3.3556 -- time: 14.2078 sec.
# ステップ( 8620 )  loss: 3.5898 -- time: 14.1014 sec.
# ステップ( 8630 )  loss: 3.4776 -- time: 14.3485 sec.
# ステップ( 8640 )  loss: 3.2550 -- time: 14.4112 sec.
# ステップ( 8650 )  loss: 3.7369 -- time: 14.0758 sec.
# ステップ( 8660 )  loss: 3.6339 -- time: 14.2358 sec.
# ステップ( 8670 )  loss: 3.0177 -- time: 14.3926 sec.
# ステップ( 8680 )  loss: 3.3114 -- time: 14.2489 sec.
# ステップ( 8690 )  loss: 3.5325 -- time: 14.2321 sec.
# ステップ( 8700 )  loss: 4.1103 -- time: 14.3769 sec.
# ステップ( 8710 )  loss: 2.9898 -- time: 14.4073 sec.
# ステップ( 8720 )  loss: 3.4009 -- time: 14.2117 sec.
# ステップ( 8730 )  loss: 3.8433 -- time: 14.3841 sec.
# ステップ( 8740 )  loss: 3.0681 -- time: 14.2554 sec.
# ステップ( 8750 )  loss: 3.3733 -- time: 14.2542 sec.
# ステップ( 8760 )  loss: 3.7246 -- time: 14.2432 sec.
# ステップ( 8770 )  loss: 3.4470 -- time: 14.1819 sec.
# ---------------------------------------
# train_loss: 628.4135 - val_loss(Every 10 epochs): 0.0000
# time:  265.7981 sec.
# ---------------------------------------
# Epoch 50/50
# ---------------------------------------
# ステップ( 8780 )  loss: 3.2165 -- time: 12.9216 sec.
# ステップ( 8790 )  loss: 3.2185 -- time: 14.4129 sec.
# ステップ( 8800 )  loss: 3.7408 -- time: 14.1842 sec.
# ステップ( 8810 )  loss: 3.4470 -- time: 14.2491 sec.
# ステップ( 8820 )  loss: 3.5186 -- time: 14.3163 sec.
# ステップ( 8830 )  loss: 3.9107 -- time: 14.3731 sec.
# ステップ( 8840 )  loss: 3.1580 -- time: 14.2361 sec.
# ステップ( 8850 )  loss: 3.2610 -- time: 14.3994 sec.
# ステップ( 8860 )  loss: 3.5925 -- time: 13.9149 sec.
